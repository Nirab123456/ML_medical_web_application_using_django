# %%
import pandas as pd 


df = pd.read_csv('nirab.csv')

# %%
# Convert all letters to lowercase
df = df.apply(lambda x: x.astype(str).str.lower())

# Save the changes to a new CSV file
df.to_csv('small.csv', index=False)

# %%
df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer  \
# 0                      125 mg/5 ml        acme laboratories ltd.
# 1                           500 mg        acme laboratories ltd.
# 2                      250 mg/vial        acme laboratories ltd.
# 3                    500 mg+400 iu        acme laboratories ltd.
# 4                    500 mg+200 iu        acme laboratories ltd.
# ...                            ...                           ...
# 1483                           nan  beximco pharmaceuticals ltd.
# 1484                           nan  incepta pharmaceuticals ltd.
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.
# 1486                  450 mg+50 mg       drug international ltd.
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.
#
#                        price
# 0                        nan
# 1     (100's pack: ৳ 598.00)
# 2       (5's pack: ৳ 100.00)
# 3         (1 x 30: ৳ 225.00)
# 4         (1 x 15: ৳ 105.00)
# ...                      ...
# 1483       (1 x 60: ৳ 37.00)
# 1484                     nan
# 1485                     nan
# 1486      (3 x 10: ৳ 240.00)
# 1487                     nan
#
# [1488 rows x 6 columns]

# %%
nan_df = df.isna()

# Count the number of NaN values in each column
nan_count = nan_df.sum()

# Print the result
print(nan_count)
# Out:
# name              0
# dosage_form       0
# generic_name      0
# strength         59
# manufacturer      0
# price           517
# dtype: int64

# %%
import pandas as pd
import numpy as np
import re

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('nirab.csv')

# Convert NaN values to 0
df = df.fillna(0)

# Define a function to calculate the price
def calculate_price(row):
    try:
        match = re.search(r'(\d+\.\d+)', str(row['price']))
        if match:
            price = float(match.group(1))
            if 'x' in str(row['price']):
                match2 = re.search(r'(\d+)\sx\s(\d+)', str(row['price']))
                if match2:
                    left = int(match2.group(1))
                    right = int(match2.group(2))
                    if right != 0:
                        return price / (left * right)
                    else:
                        return 0
            else:
                match2 = re.search(r'(\d+)', str(row['price']))
                if match2:
                    left = int(match2.group(1))
                    if left != 0:
                        return price / left
    except:
        pass
    return 0

# Apply the price calculation function to the 'price' column
df['price'] = df.apply(calculate_price, axis=1)
df['price'] = df['price'].apply(lambda x: round(x, 2))
df = df.applymap(lambda x: str(x).lower())

# Save the changes inplace
df.to_csv('price_fixed.csv', index=False)

# %%
import pandas as pd
df=pd.read_csv('D:/learn_django/tryagain/full_fixed.csv')

# %%
df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer  price
# 0                      125 mg/5 ml        acme laboratories ltd.   0.00
# 1                           500 mg        acme laboratories ltd.   5.98
# 2                      250 mg/vial        acme laboratories ltd.  20.00
# 3                    500 mg+400 iu        acme laboratories ltd.   7.50
# 4                    500 mg+200 iu        acme laboratories ltd.   7.00
# ...                            ...                           ...    ...
# 1483                             0  beximco pharmaceuticals ltd.   0.62
# 1484                             0  incepta pharmaceuticals ltd.   0.00
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.   0.00
# 1486                  450 mg+50 mg       drug international ltd.   8.00
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.   0.00
#
# [1488 rows x 6 columns]

# %%
len(df['generic_name'].unique())
# Out:
# 380

# %%
duplicates = df.duplicated()

# %%
len(duplicates)
# Out:
# 1488

# %%
df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer  price
# 0                      125 mg/5 ml        acme laboratories ltd.   0.00
# 1                           500 mg        acme laboratories ltd.   5.98
# 2                      250 mg/vial        acme laboratories ltd.  20.00
# 3                    500 mg+400 iu        acme laboratories ltd.   7.50
# 4                    500 mg+200 iu        acme laboratories ltd.   7.00
# ...                            ...                           ...    ...
# 1483                             0  beximco pharmaceuticals ltd.   0.62
# 1484                             0  incepta pharmaceuticals ltd.   0.00
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.   0.00
# 1486                  450 mg+50 mg       drug international ltd.   8.00
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.   0.00
#
# [1488 rows x 6 columns]

# %%
unique_string = 'diclofenac sodium'
subset_df = df[df['generic_name'] == unique_string]

# %%
subset_df
# Out:
#             name                  dosage_form       generic_name    strength  \
# 6        a-fenac                       tablet  diclofenac sodium       25 mg
# 47       a-fenac                          gel  diclofenac sodium      1% w/w
# 48       a-fenac                 im injection  diclofenac sodium  75 mg/3 ml
# 49       a-fenac                  suppository  diclofenac sodium     12.5 mg
# 50       a-fenac                       tablet  diclofenac sodium       50 mg
# 55       a-fenac                  suppository  diclofenac sodium       50 mg
# 142   a-fenac sr   tablet (sustained release)  diclofenac sodium      100 mg
# 400          aid                       tablet  diclofenac sodium       50 mg
# 401       aid sr   tablet (sustained release)  diclofenac sodium      100 mg
# 485       aid tr      capsule (timed release)  diclofenac sodium      100 mg
# 530      alcofen                       tablet  diclofenac sodium       50 mg
# 655   alcofen sr  capsule (sustained release)  diclofenac sodium      100 mg
# 730   alterin tr      capsule (timed release)  diclofenac sodium      100 mg
# 781      alterin                       tablet  diclofenac sodium       50 mg
# 1113     anfenac          ophthalmic solution  diclofenac sodium        0.1%
# 1179     anodyne                          gel  diclofenac sodium      1% w/w
# 1180     anodyne                       tablet  diclofenac sodium       50 mg
# 1188     anodyne          ophthalmic solution  diclofenac sodium        0.1%
# 1198  anodyne sr  capsule (sustained release)  diclofenac sodium      100 mg
# 1279       apnac                       tablet  diclofenac sodium       50 mg
# 1285    apnac sr  capsule (sustained release)  diclofenac sodium      100 mg
# 1361    apain-tr      capsule (timed release)  diclofenac sodium      100 mg
#
#                        manufacturer  price
# 6            acme laboratories ltd.   0.55
# 47           acme laboratories ltd.   0.00
# 48           acme laboratories ltd.  14.10
# 49           acme laboratories ltd.   8.07
# 50           acme laboratories ltd.   1.20
# 55           acme laboratories ltd.  15.00
# 142          acme laboratories ltd.   3.50
# 400    premier pharmaceuticals ltd.   0.80
# 401    premier pharmaceuticals ltd.   3.00
# 485    premier pharmaceuticals ltd.   3.00
# 530      aexim pharmaceuticals ltd.   0.70
# 655      aexim pharmaceuticals ltd.   1.50
# 730                euro pharma ltd.   3.00
# 781                euro pharma ltd.   1.00
# 1113      nipa pharmaceuticals ltd.   0.00
# 1179  ibn sina pharmaceuticals ltd.   0.00
# 1180  ibn sina pharmaceuticals ltd.   1.00
# 1188  ibn sina pharmaceuticals ltd.   0.00
# 1198  ibn sina pharmaceuticals ltd.   4.00
# 1279    supreme pharmaceutical ltd.   0.80
# 1285    supreme pharmaceutical ltd.   3.00
# 1361    kemiko pharmaceuticals ltd.   3.01

# %%
df['generic_name'].unique()
# Out:
# array(['cloxacillin sodium',
#        'calcium carbonate [elemental source] + vitamin d3',
#        'bromhexine hydrochloride', 'diclofenac sodium',
#        'tolperisone hydrochloride',
#        'ulipristal acetate [for emergency contraception]', 'fluorouracil',
#        'calcium carbonate [elemental source]', 'cefixime trihydrate',
#        'cholecalciferol [vitamin d3]',
#        'betacarotene + vitamin c + vitamin e', 'vitamin b1, b6 & b12',
#        'levofloxacin hemihydrate', 'chloramphenicol', 'aceclofenac',
#        'thiamine hydrochloride', 'paracetamol', 'paracetamol + caffeine',
#        'erythromycin', 'miconazole nitrate', 'ivermectin',
#        'flucloxacillin sodium', 'mebeverine hydrochloride', 'vitamin a',
#        'mifepristone + misoprostol',
#        'diclofenac sodium + lidocaine hydrochloride',
#        'diclofenac potassium',
#        'dextromethorphan + pseudoephedrine + triprolidine',
#        'amlodipine besilate + olmesartan medoxomil', 'abemaciclib',
#        'dicycloverine hydrochloride', 'albendazole', 'sodium picosulfate',
#        'azithromycin dihydrate', 'insulin glargine', 'zafirlukast',
#        'acarbose', 'salbutamol', 'isosorbide mononitrate', 'cephalexin',
#        'aluminium hydroxide + magnesium hydroxide', 'acetazolamide',
#        'ramipril', 'brimonidine tartrate + timolol maleate',
#        'abiraterone acetate', 'sodium alginate + potassium bicarbonate',
#        'pseudoephedrine + guaiphenasine + triprolidine',
#        'olmesartan medoxomil + hydrochlorothiazide',
#        'olmesartan medoxomil', 'memantine hydrochloride',
#        'cefaclor monohydrate', 'cephradine', 'tetracycline hydrochloride',
#        'oxyphenonium bromide', 'roxithromycin', 'pancreatin',
#        'dexamethasone + chloramphenicol',
#        'aluminium hydroxide + magnesium hydroxide + simethicone',
#        'atorvastatin calcium',
#        'paracetamol\xa0+\xa0tramadol\xa0hydrochloride', 'acetylcysteine',
#        'captopril', 'super antioxidant [vitamins & minerals]',
#        'acyclovir', 'ranitidine hydrochloride', 'lisinopril',
#        'acyclovir + hydrocortisone', 'ceftriaxone sodium',
#        'escitalopram oxalate', 'rabeprazole sodium', 'sparfloxacin',
#        'biphasic insulin aspart', 'oral rehydration salt [glucose based]',
#        'magnesium hydroxide',
#        '10 vitamin & 6 mineral [pregnancy and breast feeding formula]',
#        'lactulose',
#        'clobetasol propionate + neomycin sulphate + nystatin',
#        'tocilizumab', 'ketorolac tromethamine', 'alteplase',
#        'dexketoprofen', 'dapsone', 'adapalene + benzoyl peroxide',
#        'sildenafil citrate', 'ampicillin sodium', 'clobetasol propionate',
#        'levosalbutamol', 'meclizine + pyridoxine',
#        'aclidinium bromide + formoterol fumarate',
#        'cetirizine hydrochloride', 'levocetirizine dihydrochloride',
#        'zoledronic acid [for hypercalcemia]',
#        'calcium carbonate + vitamin d3 + multimineral',
#        'calcium lactate gluconate + calcium carbonate + vitamin c',
#        'dexamethasone', 'adapalene', 'tolfenamic acid',
#        'oral rehydration salt [flavore & glucose based]',
#        'meclizine hydrochloride', 'alcaftadine', 'ambroxol hydrochloride',
#        'ticagrelor', 'dextrose', 'mannitol', 'magaldrate',
#        'zoledronic acid [for osteoporosis]',
#        'insulin aspart [protamine crystallised]',
#        'sodium chloride + dextrose', 'inhaler device',
#        'bisoprolol hemifumarate', 'sulphamethoxazole + trimethoprim',
#        'amlodipine besilate', 'pioglitazone + metformin hydrochloride',
#        'bromfenac sodium',
#        'iron polymaltose complex + vitamin b complex + zinc',
#        'multivitamin & multimineral [a-z gold preparation]',
#        'vitamin b complex + zinc', 'amlodipine besilate + atenolol',
#        'pioglitazone',
#        'multivitamin & multimineral [a-z silver preparation]',
#        'insulin human [rdna]', 'ciprofloxacin', 'vitamin b complex',
#        'azilsartan medoxomil', 'prednisolone', 'roflumilast',
#        'adalimumab', 'propranolol hydrochloride',
#        'linagliptin + metformin hydrochloride', 'adenosine', 'tadalafil',
#        'efavirenz', 'empagliflozin + linagliptin', 'orlistat',
#        'diphenhydramine hydrochloride', 'cefuroxime axetil', 'adrenaline',
#        'linagliptin', 'doxorubicin hydrochloride', 'everolimus',
#        'fexofenadine hydrochloride', 'mebhydrolin napadisylate',
#        'pheniramine maleate', 'racepinephrine', 'agomelatine',
#        'alogliptin benzoate', 'aspirin + dipyridamole',
#        'afatinib dimaleate', 'griseofulvin [microsize]', 'clotrimazole',
#        'amikacin', 'favipiravir', 'oxymetazoline hydrochloride',
#        'deutetrabenazine', 'empagliflozin',
#        'empagliflozin + metformin hydrochloride', 'montelukast sodium',
#        'ketotifen fumarate', 'rupatadine fumarate',
#        'olopatadine hydrochloride', 'alpha lipoic acid',
#        'naproxen sodium', 'valacyclovir', 'isotretinoin',
#        'glycopyrronium bromide', 'digoxin', 'fluconazole',
#        'fluorometholone + tetrahydrozoline',
#        'fluorometholone + gentamicin', 'inactivated influenza vaccine',
#        'flupentixol + melitracen', 'bambuterol hydrochloride',
#        'ibuprofen', 'esmolol hydrochloride', 'domperidone maleate',
#        'cefadroxil monohydrate', 'amlodipine besilate + atorvastatin',
#        'nitazoxanide', 'doxepin', 'amoxicillin trihydrate', 'gliclazide',
#        'desloratadine', 'cefdinir', 'glimepiride', 'adefovir dipivoxil',
#        'iron + folic acid + vitamin b complex + vitamine c + zinc sulfate',
#        'losartan potassium', 'hydrochlorothiazide', 'budesonide',
#        'losartan potassium + hydrochlorothiazide', 'simethicone',
#        'betamethasone + neomycin sulphate',
#        'betamethasone + clotrimazole',
#        'almitrine bismesylate + raubasine', 'alprazolam', 'loratadine',
#        'baclofen', 'albumin',
#        'isopropyl alcohol + hydrogen peroxide + glycerol', 'entecavir',
#        'tenofovir alafenamide', 'alendronic acid', 'alectinib',
#        'epalrestat', 'levodopa + carbidopa', 'alfuzosin hydrochloride',
#        'pivmecillinam', 'quinine sulfate', 'enoxaparin sodium',
#        'tiemonium methylsulphate', 'triamcinolone acetonide',
#        'ethanol + isopropyl alcohol', 'ebastine',
#        'sodium alginate + sodium bicarbonate + calcium carbonate',
#        'calcium carbonate [algae source] + vitamin d3', 'nabumetone',
#        'potassium citrate + citric acid', 'chlorpheniramine maleate',
#        'methyl salicylate + menthol', 'sodium bicarbonate',
#        'methyl salicylate + menthol + camphor', 'crizotinib',
#        'etoricoxib', 'allylestrenol', 'pregabalin',
#        'calcium lactate gluconate + calcium carbonate + vitamin c + vitamin d3',
#        'iron + folic acid + vitamin b complex + vitamin c', 'mizolastine',
#        'eplerenone', 'fludrocortisone acetate',
#        'eucalyptol + menthol + methyl salicylate + thymol + sodium fluoride',
#        'bilastine', 'insulin device & needle',
#        'promethazine hydrochloride', 'multivitamin & multimineral',
#        'lapatinib', 'metronidazole', 'levamisole',
#        'iron polymaltose complex + folic acid + zinc + vitamin b-complex',
#        'esomeprazole', 'dithranol + boric acid + salicylic acid',
#        'alverine citrate', 'memantine + donepezil',
#        'prazosin hydrochloride', 'brigatinib', 'phospholipids',
#        'antihemophilic factor [factor viii]', 'alphanate', 'almotriptan',
#        'flurazepam', 'allopurinol', 'epinastine hydrochloride',
#        'brimonidine tartrate', 'diosmin + hesperidin', 'pemetrexed',
#        'rosuvastatin calcium', 'glimepiride + metformin',
#        'amantadine hydrochloride', 'ambrisentan',
#        'donepezil hydrochloride',
#        'bisoprolol fumarate + amlodipine besilate',
#        'metronidazole + miconazole nitrate',
#        'amitriptyline hydrochloride',
#        'amino acid, d-sorbitol with electrolytes', 'amisulpride',
#        'amino acid', 'mirtazapine', 'amiodarone hydrochloride',
#        'amino acids, glucose & electrolytes', 'aminophylline',
#        'mefenamic acid', 'iopamidol', 'sodium thiosulfate',
#        'amitriptyline hydrochloride + chlordiazepoxide',
#        'prochlorperazine maleate',
#        'fluocinolone acetonide + hydroquinone + tretinoin',
#        'amlodipine besilate + valsartan', 'levamlodipine maleate',
#        'fluphenazine + nortriptyline', 'amlexanox', 'gatifloxacin',
#        'amoxicillin + clavulanic acid',
#        'amlodipine besilate + benazepril hydrochloride',
#        'clobetasone butyrate', 'naproxen sodium + esomeprazole magnesium',
#        'tramadol hydrochloride', 'nandrolone phenylpropionate',
#        'anastrozole', 'hydrocortisone', 'clopidogrel bisulphate',
#        'tranexamic acid', 'clopidogrel + aspirin', 'omeprazole',
#        'monosemicarbazone adrenochrome', 'enalapril maleate',
#        'clomipramine hydrochloride', 'hydrocortisone + lidocaine',
#        'hyoscine butylbromide', 'cefepime hydrochloride', 'atenolol',
#        'bupivacaine hydrochloride + dextrose', 'thiopental sodium',
#        'testosterone', 'testosterone undecanoate', 'iron sucrose',
#        'sertraline hydrochloride', 'bromazepam',
#        'bisoprolol fumarate + hydrochlorothiazide',
#        'diabasic sodium phosphate + monobasic sodium phosphate',
#        'trimetazidine dihydrochloride', 'metoprolol tartrate', 'aspirin',
#        'verapamil hydrochloride', 'nitroglycerin',
#        'drospirenone + estradiol', 'terbinafine hydrochloride',
#        'midazolam', 'carbamazepine',
#        'carbonyl iron + folic acid + zinc sulfate',
#        'hydrocortisone acetate + benzyl benzoate + bismuth subgallate + bismuth oxide + balsam peru + zinc oxide',
#        'clindamycin', 'vitamin c + vitamin e',
#        'cinchocaine + hydrocortisone + neomycin + esculin', 'ondansetron',
#        'oxazepam', 'snake venom antiserum',
#        'allium cepa + heparin + allantoin', 'apixaban', 'pizotifen',
#        'ursodeoxycholic acid', 'mepyramine maleate',
#        'xylometazoline hydrochloride',
#        'sodium cromoglicate + xylometazoline hydrochloride',
#        'prasugrel hydrochloride', 'diclofenac sodium + misoprostol',
#        'multivitamin [pediatric preparation]', 'megestrol acetate',
#        'ferrous sulfate + folic acid + zinc sulfate', 'apremilast',
#        'aprepitant', 'ciprofloxacin + dexamethasone', 'insulin glulisine',
#        'linezolid', 'apalutamide', 'levodopa + benserazide',
#        'doxycycline hydrochloride', 'aluminium chloride hexahydrate',
#        'ranolazine', 'guaifenesin + levomenthol + diphenhydramine',
#        'ferrous sulfate', 'povidone iodine', 'sucralfate', 'carbetocin',
#        'multivitamin & cod liver oil', 'irbesartan',
#        'vildagliptin + metformin hydrochloride',
#        'carboxymethylcellulose sodium',
#        'carboxymethylcellulose sodium + hypromellose',
#        'polyethylene glycol',
#        'chlorhexidine gluconate + isopropyl alcohol', 'carboplatin',
#        'istradefylline', 'artemether + lumefantrine',
#        'pipecuronium bromide', 'cabergoline',
#        'telmisartan + hydrochlorothiazide',
#        'multivitamin & multimineral [a-z juniors syrup preparation]',
#        'multivitamin [water soluble]', 'aripiprazole',
#        'ferrous fumarate + folic acid',
#        'amlodipine besilate + telmisartan',
#        'econazole nitrate + triamcinolone acetonide',
#        'betamethasone + clotrimazole + gentamicin',
#        'sodium cromoglicate [2%]', 'artesunate', 'carvedilol',
#        'telmisartan', 'irbesartan + hydrochlorothiazide', 'cisplatin',
#        'betamethasone valerate'], dtype=object)

# %%
max_length = df['generic_name'].str.len().max()

# %%
# Get the value(s) with the maximum length
max_values = df[df['generic_name'].str.len() == max_length]['generic_name']

print("Maximum length:", max_length)
print("Value(s) with maximum length:")
for value in max_values:
    print(value)
# Out:
# Maximum length: 104
# Value(s) with maximum length:
# hydrocortisone acetate + benzyl benzoate + bismuth subgallate + bismuth oxide + balsam peru + zinc oxide

# %%
string = 'hydrocortisone acetate + benzyl benzoate + bismuth subgallate + bismuth oxide + balsam peru + zinc oxide'
len(string)
# Out:
# 104

# %%
df['price'] = df['price'].apply(lambda x: round(x, 2))

# %%
df
# Out:
#              name            dosage_form  \
# 0          A-Clox  Powder for Suspension
# 1          A-Clox                Capsule
# 2          A-Clox              Injection
# 3        A-Cal DX                 Tablet
# 4         A-Cal D                 Tablet
# ...           ...                    ...
# 1483  Aristovit B                 Tablet
# 1484    Aritone Z                  Syrup
# 1485  Aristoferon                  Syrup
# 1486       Ardium                 Tablet
# 1487      Ariscon        Oral Suspension
#
#                                            generic_name  \
# 0                                    Cloxacillin Sodium
# 1                                    Cloxacillin Sodium
# 2                                    Cloxacillin Sodium
# 3     Calcium Carbonate [Elemental source] + Vitamin D3
# 4     Calcium Carbonate [Elemental source] + Vitamin D3
# ...                                                 ...
# 1483                                  Vitamin B complex
# 1484                           Vitamin B Complex + Zinc
# 1485                                    Ferrous Sulfate
# 1486                               Diosmin + Hesperidin
# 1487  Sodium Alginate + Sodium Bicarbonate + Calcium...
#
#                           strength                  manufacturer  price
# 0                      125 mg/5 ml        ACME Laboratories Ltd.   0.00
# 1                           500 mg        ACME Laboratories Ltd.   5.98
# 2                      250 mg/vial        ACME Laboratories Ltd.  20.00
# 3                    500 mg+400 IU        ACME Laboratories Ltd.   7.50
# 4                    500 mg+200 IU        ACME Laboratories Ltd.   7.00
# ...                            ...                           ...    ...
# 1483                             0  Beximco Pharmaceuticals Ltd.   0.62
# 1484                             0  Incepta Pharmaceuticals Ltd.   0.00
# 1485                   200 mg/5 ml  Beximco Pharmaceuticals Ltd.   0.00
# 1486                  450 mg+50 mg       Drug International Ltd.   8.00
# 1487  (500 mg+267 mg+160 mg)/10 ml             Aristopharma Ltd.   0.00
#
# [1488 rows x 6 columns]

# %%
df = df.applymap(lambda x: str(x).lower())

# %%
df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer price
# 0                      125 mg/5 ml        acme laboratories ltd.   0.0
# 1                           500 mg        acme laboratories ltd.  5.98
# 2                      250 mg/vial        acme laboratories ltd.  20.0
# 3                    500 mg+400 iu        acme laboratories ltd.   7.5
# 4                    500 mg+200 iu        acme laboratories ltd.   7.0
# ...                            ...                           ...   ...
# 1483                             0  beximco pharmaceuticals ltd.  0.62
# 1484                             0  incepta pharmaceuticals ltd.   0.0
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.   0.0
# 1486                  450 mg+50 mg       drug international ltd.   8.0
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.   0.0
#
# [1488 rows x 6 columns]

# %%
df.to_csv('full_fixed.csv', index=False)

# %%
len(df['generic_name'].unique())
# Out:
# 380

# %%
unique = df['dosage_form'].unique()

# %%
len(unique)
# Out:
# 58

# %% [markdown]
# df.to_csv('price_fixed.csv', index=False)
