# %%
import pandas as pd 


df = pd.read_csv('nirab.csv')

# %%
# Convert all letters to lowercase
df = df.apply(lambda x: x.astype(str).str.lower())

# Save the changes to a new CSV file
df.to_csv('small.csv', index=False)

# %%
df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer  \
# 0                      125 mg/5 ml        acme laboratories ltd.
# 1                           500 mg        acme laboratories ltd.
# 2                      250 mg/vial        acme laboratories ltd.
# 3                    500 mg+400 iu        acme laboratories ltd.
# 4                    500 mg+200 iu        acme laboratories ltd.
# ...                            ...                           ...
# 1483                           nan  beximco pharmaceuticals ltd.
# 1484                           nan  incepta pharmaceuticals ltd.
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.
# 1486                  450 mg+50 mg       drug international ltd.
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.
#
#                        price
# 0                        nan
# 1     (100's pack: ৳ 598.00)
# 2       (5's pack: ৳ 100.00)
# 3         (1 x 30: ৳ 225.00)
# 4         (1 x 15: ৳ 105.00)
# ...                      ...
# 1483       (1 x 60: ৳ 37.00)
# 1484                     nan
# 1485                     nan
# 1486      (3 x 10: ৳ 240.00)
# 1487                     nan
#
# [1488 rows x 6 columns]

# %%
nan_df = df.isna()

# Count the number of NaN values in each column
nan_count = nan_df.sum()

# Print the result
print(nan_count)
# Out:
# name              0
# dosage_form       0
# generic_name      0
# strength         59
# manufacturer      0
# price           517
# dtype: int64

# %%
import pandas as pd
import numpy as np
import re

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('nirab.csv')

# Convert NaN values to 0
df = df.fillna(0)

# Define a function to calculate the price
def calculate_price(row):
    try:
        match = re.search(r'(\d+\.\d+)', str(row['price']))
        if match:
            price = float(match.group(1))
            if 'x' in str(row['price']):
                match2 = re.search(r'(\d+)\sx\s(\d+)', str(row['price']))
                if match2:
                    left = int(match2.group(1))
                    right = int(match2.group(2))
                    if right != 0:
                        return price / (left * right)
                    else:
                        return 0
            else:
                match2 = re.search(r'(\d+)', str(row['price']))
                if match2:
                    left = int(match2.group(1))
                    if left != 0:
                        return price / left
    except:
        pass
    return 0

# Apply the price calculation function to the 'price' column
df['price'] = df.apply(calculate_price, axis=1)
df['price'] = df['price'].apply(lambda x: round(x, 2))
df = df.applymap(lambda x: str(x).lower())

# Save the changes inplace
df.to_csv('price_fixed.csv', index=False)

# %% [markdown]
# load new  full_cleaned_django.csv  and will work with it

# %%
import pandas as pd

# %%
full_cleaned_django_df = pd.read_csv('full_cleaned_django.csv')

# %%
full_cleaned_django_df
# Out:
#                        name                 dosage_form  \
# 0                    a-cold                       syrup
# 1                     a-cof                       syrup
# 2                    a-clox                   injection
# 3                    a-clox                   injection
# 4                    a-clox       powder for suspension
# ...                     ...                         ...
# 29956                tanpot                      tablet
# 29957                tanpot                      tablet
# 29958                tanpot                      tablet
# 29959           tanpot-plus                      tablet
# 29960  taspia-04-mg-capsule  capsule (modified release)
#
#                                             generic_name  \
# 0                               bromhexine hydrochloride
# 1      dextromethorphan + pseudoephedrine + triprolidine
# 2                                     cloxacillin sodium
# 3                                     cloxacillin sodium
# 4                                     cloxacillin sodium
# ...                                                  ...
# 29956                                 losartan potassium
# 29957                                 losartan potassium
# 29958                                 losartan potassium
# 29959           losartan potassium + hydrochlorothiazide
# 29960                          tamsulosin  hydrochloride
#
#                          strength                 manufacturer  \
# 0                       4 mg/5 ml       acme laboratories ltd.
# 1      (10 mg+30 mg+1.25 mg)/5 ml       acme laboratories ltd.
# 2                     500 mg/vial       acme laboratories ltd.
# 3                     250 mg/vial       acme laboratories ltd.
# 4                     125 mg/5 ml       acme laboratories ltd.
# ...                           ...                          ...
# 29956                       25 mg  albion laboratories limited
# 29957                       50 mg  albion laboratories limited
# 29958                      100 mg  albion laboratories limited
# 29959               50 mg+12.5 mg  albion laboratories limited
# 29960                      0.4 mg    silco pharmaceutical ltd.
#
#                         price price_analysis      _merge
# 0       100 ml bottle:  40.12          40.12        both
# 1      100 ml bottle:  100.00         100.00        both
# 2           5's pack:  142.15          28.43        both
# 3           5's pack:  100.00          20.00        both
# 4       100 ml bottle:  45.00          45.00        both
# ...                       ...            ...         ...
# 29956                     NaN            NaN  right_only
# 29957                     NaN            NaN  right_only
# 29958                     NaN            NaN  right_only
# 29959                     NaN            NaN  right_only
# 29960                     NaN            NaN  right_only
#
# [29961 rows x 8 columns]

# %%
drop_collum= ['_merge']
full_cleaned_django_df.drop(drop_collum, axis=1, inplace=True)

# %%
full_cleaned_django_df = full_cleaned_django_df.applymap(lambda x: str(x).lower())

# %%
full_cleaned_django_df.to_csv('full_cleaned_django_2.csv', index=False)

# %%
full_cleaned_django_df
# Out:
#                        name                 dosage_form  \
# 0                    a-cold                       syrup
# 1                     a-cof                       syrup
# 2                    a-clox                   injection
# 3                    a-clox                   injection
# 4                    a-clox       powder for suspension
# ...                     ...                         ...
# 29956                tanpot                      tablet
# 29957                tanpot                      tablet
# 29958                tanpot                      tablet
# 29959           tanpot-plus                      tablet
# 29960  taspia-04-mg-capsule  capsule (modified release)
#
#                                             generic_name  \
# 0                               bromhexine hydrochloride
# 1      dextromethorphan + pseudoephedrine + triprolidine
# 2                                     cloxacillin sodium
# 3                                     cloxacillin sodium
# 4                                     cloxacillin sodium
# ...                                                  ...
# 29956                                 losartan potassium
# 29957                                 losartan potassium
# 29958                                 losartan potassium
# 29959           losartan potassium + hydrochlorothiazide
# 29960                          tamsulosin  hydrochloride
#
#                          strength                 manufacturer  \
# 0                       4 mg/5 ml       acme laboratories ltd.
# 1      (10 mg+30 mg+1.25 mg)/5 ml       acme laboratories ltd.
# 2                     500 mg/vial       acme laboratories ltd.
# 3                     250 mg/vial       acme laboratories ltd.
# 4                     125 mg/5 ml       acme laboratories ltd.
# ...                           ...                          ...
# 29956                       25 mg  albion laboratories limited
# 29957                       50 mg  albion laboratories limited
# 29958                      100 mg  albion laboratories limited
# 29959               50 mg+12.5 mg  albion laboratories limited
# 29960                      0.4 mg    silco pharmaceutical ltd.
#
#                         price price_analysis
# 0       100 ml bottle:  40.12          40.12
# 1      100 ml bottle:  100.00         100.00
# 2           5's pack:  142.15          28.43
# 3           5's pack:  100.00          20.00
# 4       100 ml bottle:  45.00          45.00
# ...                       ...            ...
# 29956                     nan            nan
# 29957                     nan            nan
# 29958                     nan            nan
# 29959                     nan            nan
# 29960                     nan            nan
#
# [29961 rows x 7 columns]

# %% [markdown]
# NOW WILL LOAD PREVIOUS FULL CLEANED DATA

# %%
previous_cleaned_df = pd.read_csv('D:/learn_django/tryagain/medicine_recomandation_data/full_fixed.csv')

# %%
previous_cleaned_df
# Out:
#              name            dosage_form  \
# 0          a-clox  powder for suspension
# 1          a-clox                capsule
# 2          a-clox              injection
# 3        a-cal dx                 tablet
# 4         a-cal d                 tablet
# ...           ...                    ...
# 1483  aristovit b                 tablet
# 1484    aritone z                  syrup
# 1485  aristoferon                  syrup
# 1486       ardium                 tablet
# 1487      ariscon        oral suspension
#
#                                            generic_name  \
# 0                                    cloxacillin sodium
# 1                                    cloxacillin sodium
# 2                                    cloxacillin sodium
# 3     calcium carbonate [elemental source] + vitamin d3
# 4     calcium carbonate [elemental source] + vitamin d3
# ...                                                 ...
# 1483                                  vitamin b complex
# 1484                           vitamin b complex + zinc
# 1485                                    ferrous sulfate
# 1486                               diosmin + hesperidin
# 1487  sodium alginate + sodium bicarbonate + calcium...
#
#                           strength                  manufacturer  price
# 0                      125 mg/5 ml        acme laboratories ltd.   0.00
# 1                           500 mg        acme laboratories ltd.   5.98
# 2                      250 mg/vial        acme laboratories ltd.  20.00
# 3                    500 mg+400 iu        acme laboratories ltd.   7.50
# 4                    500 mg+200 iu        acme laboratories ltd.   7.00
# ...                            ...                           ...    ...
# 1483                             0  beximco pharmaceuticals ltd.   0.62
# 1484                             0  incepta pharmaceuticals ltd.   0.00
# 1485                   200 mg/5 ml  beximco pharmaceuticals ltd.   0.00
# 1486                  450 mg+50 mg       drug international ltd.   8.00
# 1487  (500 mg+267 mg+160 mg)/10 ml             aristopharma ltd.   0.00
#
# [1488 rows x 6 columns]

# %% [markdown]
# #previous df dosent have proper information so we need to drop it

# %%
django_df = pd.read_csv('D:/learn_django/tryagain/django.csv')

# %%
django_df.fillna(0, inplace=True)

# %%
django_df
# Out:
#                        name                 dosage_form  \
# 0                    a-cold                       syrup
# 1                     a-cof                       syrup
# 2                    a-clox                   injection
# 3                    a-clox                   injection
# 4                    a-clox       powder for suspension
# ...                     ...                         ...
# 29956                tanpot                      tablet
# 29957                tanpot                      tablet
# 29958                tanpot                      tablet
# 29959           tanpot-plus                      tablet
# 29960  taspia-04-mg-capsule  capsule (modified release)
#
#                                             generic_name  \
# 0                               bromhexine hydrochloride
# 1      dextromethorphan + pseudoephedrine + triprolidine
# 2                                     cloxacillin sodium
# 3                                     cloxacillin sodium
# 4                                     cloxacillin sodium
# ...                                                  ...
# 29956                                 losartan potassium
# 29957                                 losartan potassium
# 29958                                 losartan potassium
# 29959           losartan potassium + hydrochlorothiazide
# 29960                          tamsulosin  hydrochloride
#
#                          strength                 manufacturer  \
# 0                       4 mg/5 ml       acme laboratories ltd.
# 1      (10 mg+30 mg+1.25 mg)/5 ml       acme laboratories ltd.
# 2                     500 mg/vial       acme laboratories ltd.
# 3                     250 mg/vial       acme laboratories ltd.
# 4                     125 mg/5 ml       acme laboratories ltd.
# ...                           ...                          ...
# 29956                       25 mg  albion laboratories limited
# 29957                       50 mg  albion laboratories limited
# 29958                      100 mg  albion laboratories limited
# 29959               50 mg+12.5 mg  albion laboratories limited
# 29960                      0.4 mg    silco pharmaceutical ltd.
#
#                         price price_analysis
# 0       100 ml bottle:  40.12          40.12
# 1      100 ml bottle:  100.00         100.00
# 2           5's pack:  142.15          28.43
# 3           5's pack:  100.00          20.00
# 4       100 ml bottle:  45.00          45.00
# ...                       ...            ...
# 29956                       0              0
# 29957                       0              0
# 29958                       0              0
# 29959                       0              0
# 29960                       0              0
#
# [29961 rows x 7 columns]

# %%
django_df['price_analysis'] = django_df['price_analysis'].str.replace(r"null", "0.00",regex=True)

# %%
django_df.to_csv('django.csv', index=False)

# %%
# Convert string values to space and replace NaN with '0.00'
django_df['price_analysis'] = django_df['price_analysis'].fillna('0.00').astype(str).str.replace('.*', ' ')

# %%
# Convert non-numeric string values to space and replace NaN with '0.00'
django_df['price_analysis'] = django_df['price_analysis'].apply(lambda x: re.sub(r'\D', ' ', x) if pd.notnull(x) else '0.00')

# %%
django_df['price_analysis'] = django_df['price_analysis'].str.replace(r" ", ".",regex=True)

# %%
# Convert 'Column2' to float
django_df['price_analysis'] = django_df['price_analysis'].astype(float)

# Check the data types of the columns
print(django_df.dtypes)
# Out:
# name               object
# dosage_form        object
# generic_name       object
# strength           object
# manufacturer       object
# price              object
# price_analysis    float64
# dtype: object

# %%
django_df['price_analysis'] = pd.to_numeric(django_df['price_analysis'], errors='coerce')

print(django_df)
# Out:
#                        name                 dosage_form  \
# 0                    a-cold                       syrup
# 1                     a-cof                       syrup
# 2                    a-clox                   injection
# 3                    a-clox                   injection
# 4                    a-clox       powder for suspension
# ...                     ...                         ...
# 29956                tanpot                      tablet
# 29957                tanpot                      tablet
# 29958                tanpot                      tablet
# 29959           tanpot-plus                      tablet
# 29960  taspia-04-mg-capsule  capsule (modified release)
#
#                                             generic_name  \
# 0                               bromhexine hydrochloride
# 1      dextromethorphan + pseudoephedrine + triprolidine
# 2                                     cloxacillin sodium
# 3                                     cloxacillin sodium
# 4                                     cloxacillin sodium
# ...                                                  ...
# 29956                                 losartan potassium
# 29957                                 losartan potassium
# 29958                                 losartan potassium
# 29959           losartan potassium + hydrochlorothiazide
# 29960                          tamsulosin  hydrochloride
#
#                          strength                 manufacturer  \
# 0                       4 mg/5 ml       acme laboratories ltd.
# 1      (10 mg+30 mg+1.25 mg)/5 ml       acme laboratories ltd.
# 2                     500 mg/vial       acme laboratories ltd.
# 3                     250 mg/vial       acme laboratories ltd.
# 4                     125 mg/5 ml       acme laboratories ltd.
# ...                           ...                          ...
# 29956                       25 mg  albion laboratories limited
# 29957                       50 mg  albion laboratories limited
# 29958                      100 mg  albion laboratories limited
# 29959               50 mg+12.5 mg  albion laboratories limited
# 29960                      0.4 mg    silco pharmaceutical ltd.
#
#                         price  price_analysis
# 0       100 ml bottle:  40.12           40.12
# 1      100 ml bottle:  100.00          100.00
# 2           5's pack:  142.15           28.43
# 3           5's pack:  100.00           20.00
# 4       100 ml bottle:  45.00           45.00
# ...                       ...             ...
# 29956                       0            0.00
# 29957                       0            0.00
# 29958                       0            0.00
# 29959                       0            0.00
# 29960                       0            0.00
#
# [29961 rows x 7 columns]

# %%
django_df.fillna(0.00, inplace=True)

# %% [markdown]
# django_df
