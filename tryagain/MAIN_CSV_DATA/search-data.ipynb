# %%
import pandas as pd 
df = pd.read_csv('old_main_data/django.csv')
df
# Out:
#                        name                 dosage_form  \
# 0                    a-cold                       syrup
# 1                     a-cof                       syrup
# 2                    a-clox                   injection
# 3                    a-clox                   injection
# 4                    a-clox       powder for suspension
# ...                     ...                         ...
# 29956                tanpot                      tablet
# 29957                tanpot                      tablet
# 29958                tanpot                      tablet
# 29959           tanpot-plus                      tablet
# 29960  taspia-04-mg-capsule  capsule (modified release)
#
#                                             generic_name  \
# 0                               bromhexine hydrochloride
# 1      dextromethorphan + pseudoephedrine + triprolidine
# 2                                     cloxacillin sodium
# 3                                     cloxacillin sodium
# ...

# %%
unique_generic_name_list= df['generic_name'].unique()
print(unique_generic_name_list)
# Out:
# ['bromhexine hydrochloride'
#  'dextromethorphan + pseudoephedrine + triprolidine' 'cloxacillin sodium'
#  ... 'natural plant extract + lactic acid' 'cutaneous spray'
#  'cyclosporine (oral)']

# %%
len(unique_generic_name_list)

with open('unique_generic_name_list.txt', 'w') as f:
    for item in unique_generic_name_list:
        f.write("%s\n" % item)

# %%
desage_forms_list=df['dosage_form'].unique()
with open('dosage_forms_list.txt', 'w') as f:
    for item in desage_forms_list:
        f.write("%s\n" % item)
