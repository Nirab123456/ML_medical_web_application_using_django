# %%
import pandas as pd 
df = pd.read_csv('main_data/side_effects.csv')

# %%
len(df['group'].unique()), len(df['indication'].unique()), len(df['generic_name'].unique())
# Out:
# (28, 2604, 1521)

# %%
df['group'].unique()
# Out:
# array(['sign_symptom', 'detailed_description', 'disease_disorder',
#        'severity', 'lab_value', 'medication', 'diagnostic_procedure',
#        'dosage', 'biological_structure', 'administration', 'duration',
#        'history', 'therapeutic_procedure', 'date', 'frequency',
#        'activity', 'qualitative_concept', 'clinical_event', 'color',
#        'quantitative_concept', 'coreference', 'age', 'subject', 'time',
#        'sex', 'texture', 'nonbiological_location', 'outcome'],
#       dtype=object)

# %%
df=df.astype('str').astype(str).apply(lambda x: x.str.lower())

# %%
specific_df = df[(df['group'] == 'sign_symptom') | (df['group'] == 'disease_disorder') | (df['group'] == 'medication')]

# %%
specific_df
# Out:
#                  group         indication       Score  \
# 0         sign_symptom   adverse reaction    0.789032
# 2         sign_symptom               pain   0.9997068
# 3         sign_symptom  adverse reactions  0.97730947
# 4     disease_disorder             rheuma   0.8858123
# 5     disease_disorder          arthritis    0.997771
# ...                ...                ...         ...
# 9281      sign_symptom              hyper   0.8536274
# 9282      sign_symptom     angio - oedema   0.9725296
# 9283      sign_symptom               rash   0.9998877
# 9288  disease_disorder          infection  0.99931407
# 9290  disease_disorder         infections  0.99749315
#
#                                            side_effects generic_name
# 0      the most common adverse reaction with adalimu...   adalimumab
# 2      the most common adverse reaction with adalimu...   adalimumab
# 3      the most common adverse reaction with adalimu...   adalimumab
# ...

# %%
words_to_check = ['side effect', 'effect', 
                  'adverse reaction','effects','effect',
                  'side effects','hyper','sync']
mask = specific_df['indication'].str.contains(r'\b(?:' + '|'.join(words_to_check) + r')\b', case=False)

# Use the .loc indexer to keep rows that have additional words or the exact words specified
filtered_df = specific_df.loc[~mask]

# %%
len(filtered_df['indication'].unique()), len(filtered_df['generic_name'].unique())
# Out:
# (1631, 1319)

# %%
filtered_df
# Out:
#                  group         indication       Score  \
# 2         sign_symptom               pain   0.9997068
# 3         sign_symptom  adverse reactions  0.97730947
# 4     disease_disorder             rheuma   0.8858123
# 5     disease_disorder          arthritis    0.997771
# 6         sign_symptom              flare  0.99773717
# ...                ...                ...         ...
# 9280  disease_disorder           agranulo    0.883303
# 9282      sign_symptom     angio - oedema   0.9725296
# 9283      sign_symptom               rash   0.9998877
# 9288  disease_disorder          infection  0.99931407
# 9290  disease_disorder         infections  0.99749315
#
#                                            side_effects generic_name
# 2      the most common adverse reaction with adalimu...   adalimumab
# 3      the most common adverse reaction with adalimu...   adalimumab
# 4      the most common adverse reaction with adalimu...   adalimumab
# ...

# %%
nausea /,/ hypotension,tightness / pressure

# %%
filtered_df.to_csv('new_data/specific_side_effect_SS_DD_M_2.csv', index=False)

# %%
specific_df.to_csv('new_data/specific_side_effect_SS_DD_M.csv', index=False)

# %%
filtered_df
# Out:
#                  group         indication       Score  \
# 2         sign_symptom               pain   0.9997068
# 3         sign_symptom  adverse reactions  0.97730947
# 4     disease_disorder             rheuma   0.8858123
# 5     disease_disorder          arthritis    0.997771
# 6         sign_symptom              flare  0.99773717
# ...                ...                ...         ...
# 9280  disease_disorder           agranulo    0.883303
# 9282      sign_symptom     angio - oedema   0.9725296
# 9283      sign_symptom               rash   0.9998877
# 9288  disease_disorder          infection  0.99931407
# 9290  disease_disorder         infections  0.99749315
#
#                                            side_effects generic_name
# 2      the most common adverse reaction with adalimu...   adalimumab
# 3      the most common adverse reaction with adalimu...   adalimumab
# 4      the most common adverse reaction with adalimu...   adalimumab
# ...

# %%
df
# Out:
#                      group         indication     Score  \
# 0             sign_symptom   adverse reaction  0.789032
# 1     detailed_description     injection site  0.789507
# 2             sign_symptom               pain  0.999707
# 3             sign_symptom  adverse reactions  0.977309
# 4         disease_disorder             rheuma  0.885812
# ...                    ...                ...       ...
# 9286  diagnostic_procedure              trans  0.999882
# 9287  diagnostic_procedure          bilirubin  0.928353
# 9288      disease_disorder          infection  0.999314
# 9289               subject            elderly  0.766157
# 9290      disease_disorder         infections  0.997493
#
#                                            side_effects generic_name
# 0      the most common adverse reaction with adalimu...   adalimumab
# 1      the most common adverse reaction with adalimu...   adalimumab
# 2      the most common adverse reaction with adalimu...   adalimumab
# ...
