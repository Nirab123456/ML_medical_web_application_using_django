# %%
import pandas as pd 

df = pd.read_csv('main_data/new_contradictions_df.csv')

# %%
len(df['contraindication_result'].unique())

# %%
import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")

class DRUG_CLASS_CLASSIFICATION():

    def __init__(self):
        self.pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0) # pass device=0 if using gpu
        df = pd.read_csv('main_data/new_contradictions_df.csv')
        drug_class_list = df['contraindications_description'].unique().tolist()
        # Remove nan values from the list
        drug_class_list = [item for item in drug_class_list if not pd.isna(item)]
        self.all_details = drug_class_list

    def classify_presciption_drugs(self):
        all_results = []
        all_details = self.all_details
        print(f'All Details: {all_details}')    
        # Pass the entire all_details list to the pipeline
        full_results = self.pipe(all_details)
        print(f'Results: {full_results}')
        for sentence_result, detail in zip(full_results, all_details):
            for result in sentence_result:
                if result is not None:
                    print(f'Result: {result}')
                    if len(str(result['word'])) >= 4 and '#' not in str(result['word']):
                        all_results.append({'Entity Group': result['entity_group'], 'Word': str(result['word']), 'Score': result['score'], 'Sentence': detail})
        # Return an empty DataFrame if no results are found
        if not all_results:
            return pd.DataFrame(columns=['Entity Group', 'Word', 'Score', 'Sentence'])
        return pd.DataFrame(all_results)

# Create an instance of the DRUG_CLASS_CLASSIFICATION class
drug_classifier = DRUG_CLASS_CLASSIFICATION()

# Classify the prescription drugs and save results in a pandas DataFrame
results_df = drug_classifier.classify_presciption_drugs()

# %%
results_df.to_csv('new_data/djang_base_contradiction_1.csv', index=False)

# %%
results_df = pd.read_csv('new_data/djang_base_contradiction_1.csv')

# %%
len(results_df['Entity Group'].unique())
# Out:
# 29

# %%
df=results_df

# %%
new_column_names = {
    'generic_name': 'contraindications_description',
}

# Use the rename method to rename the columns
df.rename(columns=new_column_names, inplace=True)

# %%
df=df.astype('str').astype(str).apply(lambda x: x.str.lower())

# %%
df
# Out:
#                      group            indication       score  \
# 0             sign_symptom      hypersensitivity  0.99985325
# 1               medication                  toad   0.9997948
# 2               medication        acyclovircream   0.9951826
# 3             sign_symptom                 hyper   0.8871652
# 4               medication               aciclov  0.72187907
# ...                    ...                   ...         ...
# 6636              severity                severe  0.99654263
# 6637      disease_disorder                 renal  0.85930777
# 6638      disease_disorder             hepatitis   0.9997025
# 6639  detailed_description                  long  0.98967594
# 6640                   age  under 7 years of age   0.9818188
#
#                           contraindications_description
# 0     adalimumab should not be administered to patie...
# 1     adalimumab should not be administered to patie...
# 2     acyclovircream is contraindicated in patients ...
# 3     acyclovircream is contraindicated in patients ...
# 4     aciclovir is contraindicated in patients known...
# ...                                                 ...
# 6636  zafirlukast should not be given to patients wh...
# 6637  zafirlukast should not be given to patients wh...
# 6638  zafirlukast should not be given to patients wh...
# 6639  zafirlukast should not be given to patients wh...
# 6640  zafirlukast should not be given to patients wh...
#
# [6641 rows x 4 columns]

# %%
specific_df = df[(df['group'] == 'history') | (df['group'] == 'disease_disorder') | (df['group'] == 'medication') | (df['group'] == 'subject' ) | (df['group'] == 'family_history') ]

# %%
specific_df.reset_index(inplace=True)

# %%
specific_df.drop(columns=['index'], inplace=True)
# Out:
# C:\Users\rifat\AppData\Local\Temp\ipykernel_20780\2394523933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_df.drop(columns=['index'], inplace=True)

# %%
specific_df
# Out:
#                  group      indication       score  \
# 0           medication            toad   0.9997948
# 1           medication  acyclovircream   0.9951826
# 2           medication         aciclov  0.72187907
# 3           medication       acyclovir   0.9977528
# 4           medication       acyclovir  0.99675465
# ...                ...             ...         ...
# 2743  disease_disorder     hepatitis b  0.99699664
# 2744  disease_disorder         c virus   0.9962046
# 2745        medication        zaleplon   0.9051752
# 2746  disease_disorder           renal  0.85930777
# 2747  disease_disorder       hepatitis   0.9997025
#
#                           contraindications_description
# 0     adalimumab should not be administered to patie...
# 1     acyclovircream is contraindicated in patients ...
# 2     aciclovir is contraindicated in patients known...
# 3     acyclovir is contraindicated in patients known...
# 4     acyclovir is contraindicated in patients known...
# ...                                                 ...
# 2743  hypersensitivity; abnormally low neutrophil co...
# 2744  hypersensitivity; abnormally low neutrophil co...
# 2745  zaleplon is contraindicated in patients with k...
# 2746  zafirlukast should not be given to patients wh...
# 2747  zafirlukast should not be given to patients wh...
#
# [2748 rows x 4 columns]

# %%
full_df= pd.read_csv('new_data/contraindication_result.csv')

# %%
selected_columns = ['generic_name', 'contraindications_description','contraindication_result']
full_new_df = full_df[selected_columns]
full_new_df.rename(columns={'side_effects_description': 'side_effects'}, inplace=True)
# Out:
# C:\Users\rifat\AppData\Local\Temp\ipykernel_20780\451172108.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_new_df.rename(columns={'side_effects_description': 'side_effects'}, inplace=True)

# %%
merged_df = specific_df.merge(full_new_df, on='contraindications_description', how='left')

# %%
full_new_df
# Out:
#                     generic_name  \
# 0                     adalimumab
# 1     acyclovir + hydrocortisone
# 2            acyclovir (topical)
# 3               acyclovir (oral)
# 4         acyclovir (ophthalmic)
# ...                          ...
# 1703                  zinc oxide
# 1704                zinc orotate
# 1705                  zidovudine
# 1706                    zaleplon
# 1707                 zafirlukast
#
#                           contraindications_description  \
# 0     adalimumab should not be administered to patie...
# 1                   there is no known contraindication.
# 2     acyclovircream is contraindicated in patients ...
# 3     aciclovir is contraindicated in patients known...
# 4     acyclovir is contraindicated in patients known...
# ...                                                 ...
# 1703  known hypersensitivity to any component of the...
# 1704                                  no data available
# 1705  hypersensitivity; abnormally low neutrophil co...
# 1706  zaleplon is contraindicated in patients with k...
# 1707  zafirlukast should not be given to patients wh...
#
#                                 contraindication_result
# 0     hypersensitivity toadalimumab or any of its co...
# 1                    there is no known contraindication
# 2                                      hypersensitivity
# 3                           hypersensitive to aciclovir
# 4                             acyclovir or valacyclovir
# ...                                                 ...
# 1703  known hypersensitivity to any component of the...
# 1704                                  no data available
# 1705               concomitant use with interferon alfa
# 1706          hypersensitivity to any of its components
# 1707  patients with a history of moderate or severe ...
#
# [1708 rows x 3 columns]

# %%
merged_df.to_csv('new_data/djang_main_contradiction_1.csv', index=False)

# %%
merged_df.replace('nan', np.nan, inplace=True)
# Out:
#                  group      indication       score  \
# 0           medication            toad   0.9997948
# 1           medication  acyclovircream   0.9951826
# 2           medication         aciclov  0.72187907
# 3           medication       acyclovir   0.9977528
# 4           medication       acyclovir  0.99675465
# ...                ...             ...         ...
# 2762  disease_disorder     hepatitis b  0.99699664
# 2763  disease_disorder         c virus   0.9962046
# 2764        medication        zaleplon   0.9051752
# 2765  disease_disorder           renal  0.85930777
# 2766  disease_disorder       hepatitis   0.9997025
#
#                           contraindications_description  \
# 0     adalimumab should not be administered to patie...
# 1     acyclovircream is contraindicated in patients ...
# 2     aciclovir is contraindicated in patients known...
# 3     acyclovir is contraindicated in patients known...
# 4     acyclovir is contraindicated in patients known...
# ...                                                 ...
# 2762  hypersensitivity; abnormally low neutrophil co...
# 2763  hypersensitivity; abnormally low neutrophil co...
# 2764  zaleplon is contraindicated in patients with k...
# 2765  zafirlukast should not be given to patients wh...
# 2766  zafirlukast should not be given to patients wh...
#
#                 generic_name  \
# 0                 adalimumab
# 1        acyclovir (topical)
# 2           acyclovir (oral)
# 3     acyclovir (ophthalmic)
# 4     acyclovir (ophthalmic)
# ...                      ...
# 2762              zidovudine
# 2763              zidovudine
# 2764                zaleplon
# 2765             zafirlukast
# 2766             zafirlukast
#
#                                 contraindication_result
# 0     hypersensitivity toadalimumab or any of its co...
# 1                                      hypersensitivity
# 2                           hypersensitive to aciclovir
# 3                             acyclovir or valacyclovir
# 4                             acyclovir or valacyclovir
# ...                                                 ...
# 2762               concomitant use with interferon alfa
# 2763               concomitant use with interferon alfa
# 2764          hypersensitivity to any of its components
# 2765  patients with a history of moderate or severe ...
# 2766  patients with a history of moderate or severe ...
#
# [2767 rows x 6 columns]

# %%
merged_df['group'].unique()
# Out:
# array(['medication', 'history', 'disease_disorder', 'family_history',
#        'subject'], dtype=object)

# %%
word_replacements = {
    'medication': 'contradicted drug',
    'history': 'contradicted patient history',
    'disease_disorder': 'contradicted disease',
    'family_history': 'contradicted family history',
    'subject': 'contradicted subject'
}

# Use the replace() method to replace the words in the 'column_name' column
merged_df['group'] = merged_df['group'].replace(word_replacements, regex=True)

# %%
merged_df.to_csv('new_data/djang_main_contradiction_2.csv', index=False)

# %%
merged_df
# Out:
#                      group      indication       score  \
# 0        contradicted drug            toad   0.9997948
# 1        contradicted drug  acyclovircream   0.9951826
# 2        contradicted drug         aciclov  0.72187907
# 3        contradicted drug       acyclovir   0.9977528
# 4        contradicted drug       acyclovir  0.99675465
# ...                    ...             ...         ...
# 2762  contradicted disease     hepatitis b  0.99699664
# 2763  contradicted disease         c virus   0.9962046
# 2764     contradicted drug        zaleplon   0.9051752
# 2765  contradicted disease           renal  0.85930777
# 2766  contradicted disease       hepatitis   0.9997025
#
#                           contraindications_description  \
# 0     adalimumab should not be administered to patie...
# 1     acyclovircream is contraindicated in patients ...
# 2     aciclovir is contraindicated in patients known...
# 3     acyclovir is contraindicated in patients known...
# 4     acyclovir is contraindicated in patients known...
# ...                                                 ...
# 2762  hypersensitivity; abnormally low neutrophil co...
# 2763  hypersensitivity; abnormally low neutrophil co...
# 2764  zaleplon is contraindicated in patients with k...
# 2765  zafirlukast should not be given to patients wh...
# 2766  zafirlukast should not be given to patients wh...
#
#                 generic_name  \
# 0                 adalimumab
# 1        acyclovir (topical)
# 2           acyclovir (oral)
# 3     acyclovir (ophthalmic)
# 4     acyclovir (ophthalmic)
# ...                      ...
# 2762              zidovudine
# 2763              zidovudine
# 2764                zaleplon
# 2765             zafirlukast
# 2766             zafirlukast
#
#                                 contraindication_result
# 0     hypersensitivity toadalimumab or any of its co...
# 1                                      hypersensitivity
# 2                           hypersensitive to aciclovir
# 3                             acyclovir or valacyclovir
# 4                             acyclovir or valacyclovir
# ...                                                 ...
# 2762               concomitant use with interferon alfa
# 2763               concomitant use with interferon alfa
# 2764          hypersensitivity to any of its components
# 2765  patients with a history of moderate or severe ...
# 2766  patients with a history of moderate or severe ...
#
# [2767 rows x 6 columns]

# %%
words_to_check = ['side effect', 'effect', 
                  'adverse reaction','effects','effect',
                  'side effects','hyper','sync']
mask = specific_df['indication'].str.contains(r'\b(?:' + '|'.join(words_to_check) + r')\b', case=False)

# Use the .loc indexer to keep rows that have additional words or the exact words specified
filtered_df = specific_df.loc[~mask]
