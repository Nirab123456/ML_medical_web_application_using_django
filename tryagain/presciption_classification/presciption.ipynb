# %%
import pandas as pd 
df = pd.read_csv('cleaned_generic_df_main.csv')
drug_class_list = df['drug_class'].unique().tolist()

# %%
len(drug_class_list)
# Out:
# 359

# %%
drug_class_list
# Out:
# ['immunosuppressant',
#  'hydrocortisone & combined preparations',
#  'topical antiviral preparations',
#  'herpes simplex & varicella-zoster virus infections',
#  'ophthalmic anti-viral products',
#  'antidote preparations',
#  'combined bronchodilators',
#  'oral retinoid preparations',
#  'haemodialysis solutions',
#  'carbonic anhydrase inhibitor',
#  'non-steroidal anti-inflammatory drugs (nsaids)',
#  'drugs for osteoarthritis',
#  'herbal and nutraceuticals',
#  'drugs used in gout',
#  nan,
#  'bph/ urinary retention/ urinary incontinence',
#  'vitamin in bone formation',
#  'combined preparations: inhibiting bone resorption',
#  'bisphosphonate preparations',
#  'protein kinase inhibitor',
#  'ophthalmic anti-allergic preparations',
#  'plasma expanders',
#  'anthelmintic',
#  'atypical anti-depressant drugs',
#  'cytotoxic chemotherapy',
#  'tyrosine kinase inhibitor',
#  'vaccines, anti-sera & immunoglobulin',
#  'other adrenoceptor stimulants',
#  'supplements & adjuvant therapy',
#  'drugs used in chronic kidney dialysis',
#  'parenteral nutritional preparations',
#  'aminoglycosides',
#  'cough expectorants & mucolytics',
#  'anti-hypertensive',
#  'respiratory viral infections (influenza)',
#  'anticholinergics',
#  'antacid with laxative action',
#  'antacids',
#  'miscellaneous topical agents',
#  'fibrinolytics (thrombolytics)',
#  'benzodiazepine sedatives',
#  'haemostatics',
#  'prostaglandin analogues',
#  'other preparations',
#  'topical antifungal preparations',
#  'combined antihypertensive preparations',
#  'anti-anginal & lipid lowering drugs',
#  'calcium-channel blockers',
#  'combined anxiolytics & anti-depressant drugs',
#  'tricyclic anti-depressant',
#  'atypical neuroleptic drugs',
#  'potassium channel blockers',
#  'bronchodilator',
#  'bulk-forming laxatives',
#  'anti-malarial drugs',
#  'cns stimulant drugs',
#  'immunomodulator',
#  'anti-emetic drugs',
#  'disease-modifying antirheumatic drugs (dmards)',
#  'anti-oxidant multivitamin multimineral preparations',
#  'antihaemophilic factor',
#  'other ophthalmic preparations',
#  'echinocandins',
#  'topical analgesics',
#  'specific mineral preparations',
#  'anti-histamine preparations',
#  'acne treatment preparations',
#  'cytotoxic immunosuppressants',
#  'targeted cancer therapy',
#  'drugs for erectile dysfunction',
#  'mydriatic and cycloplegic agents',
#  'non depolarizing muscle relaxants',
#  'other anti-anginal & anti-ischaemic drugs',
#  'other lipid regulating drugs',
#  'beta-adrenoceptor blocking drugs',
#  'anticholinergics (antimuscarinics)/ anti-spasmodics',
#  'anti-fungal or anti-bacterial ear drops',
#  'nasal steroid preparations',
#  'respiratory corticosteroids',
#  'contrast medium for diagnostic procedures',
#  'short-acting selective & 2-adrenoceptor stimulants',
#  'irrigation during various surgical procedures',
#  'centrally acting skeletal muscle relaxants',
#  'ophthalmic antibacterial drugs',
#  'other beta-lactam antibiotics',
#  'macrolides',
#  'cholagogues, cholelitholytics & hepatic protectors',
#  'betamethasone & combined preparations',
#  'corticosteroid',
#  "drugs used in meniere's diseases",
#  'anti-oxidant multivitamin preparations',
#  'benzylpenicillin & phenoxymethyl penicillin',
#  'parasiticidal preparations',
#  'other scalp preparations',
#  'topical anti-inflammatory preparations',
#  'other antifungal preparations',
#  'topical local anesthetics',
#  'vitamin-e preparations',
#  'local & surface anesthesia',
#  'long acting penicillin',
#  'stimulant purgatives',
#  'combination insulin',
#  'drugs for miotics and glaucoma',
#  'non-sedating antihistamines',
#  'hormonal chemotherapy',
#  'anti-platelet drugs',
#  'aural steroid & antibiotic combined preparations',
#  'phlebotonic & vascular protecting preparation',
#  'ophthalmic steroid - antibiotic combined preparations',
#  'other topical corticosteroids',
#  'bleaching and disinfectants',
#  'ophthalmic non-steroid drugs',
#  'enzymes',
#  'adjunct anti-epileptic drugs',
#  'benzodiazepine antagonist',
#  'anti adrenergic agent (beta blockers)',
#  'angiotensin-ll receptor blocker',
#  'nasal anti-histamine preparations',
#  'topical vitamin d & related preparations',
#  'local antipruritic',
#  'painkiller muscle relaxant',
#  'antiparkinson drugs',
#  'drugs used in vaginal and vulval condition',
#  'cough suppressant',
#  'regional anesthesia',
#  'loop diuretics',
#  'ulcerative colitis',
#  'nasal decongestants & other nasal preparations',
#  'oral nutritional preparations',
#  'minerals in bone formation',
#  'specific mineral & vitamin combined preparations',
#  'supportive care therapy',
#  'drugs used in ano-rectal region',
#  'vaso protective',
#  'broad spectrum penicillins',
#  'anti-fibrinolytic drugs',
#  'other genito-urinary preparations',
#  'drugs acting on the uterus',
#  'iron, vitamin & mineral combined preparation',
#  'iron & vitamin combined preparations',
#  'anti-thyroid drugs',
#  'primary anti-epileptic drugs',
#  'angiotensin-converting enzyme (ace) inhibitors',
#  'emollients & combined preparations',
#  'sodium-glucose cotransporter-2 (sglt2) inhibitors',
#  'hyperkalaemia products',
#  'dipeptidyl peptidase-4 (dpp-4) inhibitor',
#  '5-ht agonists',
#  'cerebral vasodilator & neurosensory oxygenator drugs',
#  'female sex hormones',
#  'second generation cephalosporins',
#  'third generation cephalosporins',
#  'fourth generation cephalosporins',
#  'first generation cephalosporins',
#  'alpha adrenoceptor blocking drugs',
#  'drugs for dry eyes',
#  'locally acting skeletal muscle relaxants',
#  'paroxysmal supraventricular tachycardia (psvt)',
#  'hepatic viral infections (hepatitis b)',
#  'topical retinoid and related preparations',
#  'aural anti-bacterial preparations',
#  'drugs affecting (inhibiting) gonadotrophin',
#  'sedating anti-histamine',
#  'beta-blockers',
#  'alpha-glucosidase inhibitor',
#  'drugs for hiv / anti-retroviral drugs',
#  'intravenous fluid preparations',
#  'thiazide diuretics & related drugs',
#  'chlorhexidine & chloroxylenol preparations',
#  'other antibacterial preparation',
#  'ssris & related anti-depressant drugs',
#  'anti-diarrhoeal antimicrobial drugs',
#  'anti vertigo drugs',
#  'compound steroidal preparations',
#  'calcium regulator',
#  'peripheral vasodilator drugs: intermittent claudication',
#  'centrally acting antihypertensive drugs (central sympatholytic)',
#  'tricyclic & related anti-depressant drugs',
#  'drugs for infertility',
#  'clobetasol / clobetasone & combined preparations',
#  'benzodiazepine hypnotics',
#  'topical antibiotic & retinoid preparations',
#  'benzoyl peroxide, azelaic acid & other preparations',
#  'specific combined vitamin preparations',
#  'coal-tar preparations',
#  'penicillinase-resistant penicillins',
#  'oral preparations',
#  'drugs for subcutaneous and mycoses',
#  'ophthalmic anti-fungal products',
#  'aural anti-fungal preparations',
#  'hepatic viral infections (hepatitis c)',
#  'trophic hormones & related synthetic drugs',
#  'oral hormonal preparations for acne',
#  'vitamin-b preparations',
#  'inhibiting bone resorption',
#  '4-quinolone preparations',
#  'glucocorticoids',
#  'carboxylic acids and derivatives',
#  'haematopoietic agents',
#  'parenteral anti-coagulants',
#  'combined cough suppressants',
#  'miscellaneous sedatives & hypnotics',
#  'proton pump inhibitor',
#  'serotonin-norepinephrine reuptake inhibitor (snri)',
#  'oral contraceptive preparations',
#  'synthetic analogue of adh',
#  'ophthalmic steroid preparations',
#  'other anti-protozoals',
#  'combination oral hypoglycemic preparations',
#  'enema & bowel cleansing solution',
#  'combined cough expectorants',
#  'drugs for dementia',
#  'motility stimulants',
#  'stool softener',
#  'cerumenolytic',
#  'inotropic-sympathomimetics',
#  'dithranol & combined preparations',
#  'membrane stabilizing agent (sodium channel blockers)',
#  'amoebicides',
#  'positive inotropic drugs',
#  'hair growth inhibitor',
#  'triamcinolone & combined preparations',
#  'glp-1 receptor agonists',
#  'tetracycline group of drugs',
#  'drugs for haemolytic hypoplastic & renal anemia',
#  'potassium-sparing diuretics',
#  'aldose reductase inhibitor',
#  'prokinetic drugs',
#  'haemostatic drugs',
#  'gonadotropin-releasing hormone (gnrh) antagonist',
#  'anti h. pylori drugs',
#  'topical antibiotics for acne',
#  'ergot alkaloids',
#  'drugs for menopausal symptoms: hormone replacement therapy',
#  'anti-tubercular chemotherapeutics',
#  'oral iron preparations',
#  'parenteral iron preparations',
#  'opioid analgesics',
#  'fibrates',
#  'anti-viral drugs',
#  'ezetimibe',
#  'fluocinolone & combined preparations',
#  'miscellaneous prophylactic migraine preparations',
#  'phenothiazine drugs',
#  'phenothiazine related drugs',
#  'preparations for ophthalmic diagnosis',
#  'hydroquinone preparations',
#  'intracellular antibiotic',
#  'long-acting selective -adrenoceptor stimulants',
#  'drugs for megaloblastic anemia',
#  'fluticasone & combined preparations topical',
#  'sulfonylureas',
#  'crystal violet/ gentian violet preparations',
#  'topical antibiotic preparations',
#  'dyslipidaemic agents',
#  'irrigation solution used in urological surgery',
#  'osmotic purgatives',
#  'stimulation of cartilage formation',
#  'general (inhalation) anesthetics',
#  'drugs used in tremor, tics & related disorder',
#  'water purifying agent',
#  'drugs used for rheumatoid arthritis',
#  'oxidising agent with antibacterial and antiviral properties',
#  'hormone preparations for other uses',
#  'sunblock preparation',
#  'nicotinic acid group',
#  'piperidinyl-benzisoxazole derivative',
#  'anticholinergic bronchodilators',
#  'immunological chemotherapy',
#  'rapid acting insulin',
#  'medium acting insulin',
#  'long acting insulin',
#  'oral retinoids for acne',
#  'nitrates: coronary vasodilators',
#  'dressing products for wounds/burns/ulcers',
#  'cromoglycate & related drugs',
#  'non opioid analgesics',
#  'general (intravenous) anesthetics',
#  'digestive enzyme',
#  'drugs for muscular energy metabolism',
#  'other drugs for migraine',
#  'thyroid drugs & hormone',
#  'emergency contraceptive pill',
#  'anti-histamine & decongestant',
#  'anti-diarrhoeal',
#  'anti-manic drugs',
#  'osmotic diuretics',
#  'electrolytes preparations',
#  'other laxative preparations',
#  'anti-alzheimer drugs',
#  'methoxsalen preparation',
#  'biguanides',
#  'aminosalicylates',
#  'leishmaniacides',
#  'leukotriene receptor antagonists',
#  'multi-vitamin & multi-mineral combined preparations',
#  'meglitinide analogues',
#  'ophthalmic non-steroid combined preparations',
#  'hormone in bone formation by stimulation',
#  'respiratory stimulants: analeptics',
#  'potassium-channel activator',
#  'anti-cholinesterases',
#  'anti-infective & anesthetic combined preparations',
#  'ophthalmic and topical antibacterial products',
#  'farnesoid x receptor agonists',
#  'alpha and beta-adrenergic agonist',
#  'h2 receptor antagonist',
#  'systemic urinary anti- infective',
#  'anti-diarrhoeal antiprotozoal',
#  'oral electrolytes preparations',
#  'antihistamines anti-allergies & hypo-sensitisation',
#  'growth hormone antagonist',
#  'anti neoplastic preparations',
#  'vasoconstrictor/venotonic',
#  'ocular perioperative drugs',
#  'appetite suppressant drugs/anti-obesity drugs',
#  'peritoneal dialysis solution',
#  'hematopoietic drug',
#  'mecillinams',
#  'thiazolidinedione group',
#  'drugs affecting the immune response',
#  'drugs affecting exocrine secretions',
#  'vitamin-k preparations',
#  'iodine compounds (anti-septic preparations)',
#  'prevention of repeated kidney stone formation',
#  'drugs used in myasthenia gravis',
#  'decongestant',
#  'drugs for age-related macular degeneration (amd)',
#  'oral anti-coagulants',
#  'neurodegenerative disease drugs / neuromuscular disorder drugs',
#  'combined anti- tubercular preparations',
#  'anti-tubercular antibiotics',
#  'combined preparations',
#  'topical salicylic preparation',
#  'pyrrolopyrimidines',
#  'drugs for reduction of serum phosphorus in patients with esrd',
#  'non-prostanoid ip prostacyclin receptor agonist',
#  'hormone in bone formation by inhibiting bone resorption',
#  'mast cell stabiliser',
#  'anti-dyspeptic/carminatives',
#  'drugs for lens opacification',
#  'vasodilator antihypertensive drugs',
#  'anticavity mouthwash',
#  'sulphonamides & trimethoprim',
#  'drugs for irritable bowel syndrome',
#  'chelating complex',
#  'drugs for growth failure',
#  'depolarizing muscle relaxants',
#  'male sex hormones (androgens)',
#  'glycopeptide',
#  'selective vasopressin v2-receptor antagonist',
#  'central depolarizing muscle relaxants',
#  'anti-gallstones drugs: bile acids',
#  'topical urea preparations',
#  'vitamin-a preparations',
#  'stimulator of soluble guanylate cyclase',
#  'drugs used in substance dependence',
#  'vitamin-c preparations',
#  'drugs used in diaper rash']

# %%
demo = ['drugs used in substance dependence',
 'vitamin-c preparations',
 'drugs used in diaper rash']

# %%
import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")

class DRUG_CLASS_CLASSIFICATION():

    def __init__(self):
        self.pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0) # pass device=0 if using gpu
        df = pd.read_csv('cleaned_generic_df_main.csv')
        drug_class_list = df['drug_class'].unique().tolist()
        # Remove nan values from the list
        drug_class_list = [item for item in drug_class_list if not pd.isna(item)]
        self.all_details = drug_class_list

    def classify_presciption_drugs(self):
        all_results = []
        all_details = self.all_details
        print(f'All Details: {all_details}')    
        # Pass the entire all_details list to the pipeline
        full_results = self.pipe(all_details)
        print(f'Results: {full_results}')
        for sentence_result, detail in zip(full_results, all_details):
            for result in sentence_result:
                if result is not None:
                    print(f'Result: {result}')
                    if len(str(result['word'])) >= 4 and '#' not in str(result['word']):
                        all_results.append({'Entity Group': result['entity_group'], 'Word': str(result['word']), 'Score': result['score'], 'Sentence': detail})
        # Return an empty DataFrame if no results are found
        if not all_results:
            return pd.DataFrame(columns=['Entity Group', 'Word', 'Score', 'Sentence'])
        return pd.DataFrame(all_results)

# Create an instance of the DRUG_CLASS_CLASSIFICATION class
drug_classifier = DRUG_CLASS_CLASSIFICATION()

# Classify the prescription drugs and save results in a pandas DataFrame
results_df = drug_classifier.classify_presciption_drugs()

# Print the DataFrame
print(results_df)
# Out:
# All Details: ['immunosuppressant', 'hydrocortisone & combined preparations', 'topical antiviral preparations', 'herpes simplex & varicella-zoster virus infections', 'ophthalmic anti-viral products', 'antidote preparations', 'combined bronchodilators', 'oral retinoid preparations', 'haemodialysis solutions', 'carbonic anhydrase inhibitor', 'non-steroidal anti-inflammatory drugs (nsaids)', 'drugs for osteoarthritis', 'herbal and nutraceuticals', 'drugs used in gout', 'bph/ urinary retention/ urinary incontinence', 'vitamin in bone formation', 'combined preparations: inhibiting bone resorption', 'bisphosphonate preparations', 'protein kinase inhibitor', 'ophthalmic anti-allergic preparations', 'plasma expanders', 'anthelmintic', 'atypical anti-depressant drugs', 'cytotoxic chemotherapy', 'tyrosine kinase inhibitor', 'vaccines, anti-sera & immunoglobulin', 'other adrenoceptor stimulants', 'supplements & adjuvant therapy', 'drugs used in chronic kidney dialysis', 'parenteral nutritional preparations', 'aminoglycosides', 'cough expectorants & mucolytics', 'anti-hypertensive', 'respiratory viral infections (influenza)', 'anticholinergics', 'antacid with laxative action', 'antacids', 'miscellaneous topical agents', 'fibrinolytics (thrombolytics)', 'benzodiazepine sedatives', 'haemostatics', 'prostaglandin analogues', 'other preparations', 'topical antifungal preparations', 'combined antihypertensive preparations', 'anti-anginal & lipid lowering drugs', 'calcium-channel blockers', 'combined anxiolytics & anti-depressant drugs', 'tricyclic anti-depressant', 'atypical neuroleptic drugs', 'potassium channel blockers', 'bronchodilator', 'bulk-forming laxatives', 'anti-malarial drugs', 'cns stimulant drugs', 'immunomodulator', 'anti-emetic drugs', 'disease-modifying antirheumatic drugs (dmards)', 'anti-oxidant multivitamin multimineral preparations', 'antihaemophilic factor', 'other ophthalmic preparations', 'echinocandins', 'topical analgesics', 'specific mineral preparations', 'anti-histamine preparations', 'acne treatment preparations', 'cytotoxic immunosuppressants', 'targeted cancer therapy', 'drugs for erectile dysfunction', 'mydriatic and cycloplegic agents', 'non depolarizing muscle relaxants', 'other anti-anginal & anti-ischaemic drugs', 'other lipid regulating drugs', 'beta-adrenoceptor blocking drugs', 'anticholinergics (antimuscarinics)/ anti-spasmodics', 'anti-fungal or anti-bacterial ear drops', 'nasal steroid preparations', 'respiratory corticosteroids', 'contrast medium for diagnostic procedures', 'short-acting selective & 2-adrenoceptor stimulants', 'irrigation during various surgical procedures', 'centrally acting skeletal muscle relaxants', 'ophthalmic antibacterial drugs', 'other beta-lactam antibiotics', 'macrolides', 'cholagogues, cholelitholytics & hepatic protectors', 'betamethasone & combined preparations', 'corticosteroid', "drugs used in meniere's diseases", 'anti-oxidant multivitamin preparations', 'benzylpenicillin & phenoxymethyl penicillin', 'parasiticidal preparations', 'other scalp preparations', 'topical anti-inflammatory preparations', 'other antifungal preparations', 'topical local anesthetics', 'vitamin-e preparations', 'local & surface anesthesia', 'long acting penicillin', 'stimulant purgatives', 'combination insulin', 'drugs for miotics and glaucoma', 'non-sedating antihistamines', 'hormonal chemotherapy', 'anti-platelet drugs', 'aural steroid & antibiotic combined preparations', 'phlebotonic & vascular protecting preparation', 'ophthalmic steroid - antibiotic combined preparations', 'other topical corticosteroids', 'bleaching and disinfectants', 'ophthalmic non-steroid drugs', 'enzymes', 'adjunct anti-epileptic drugs', 'benzodiazepine antagonist', 'anti adrenergic agent (beta blockers)', 'angiotensin-ll receptor blocker', 'nasal anti-histamine preparations', 'topical vitamin d & related preparations', 'local antipruritic', 'painkiller muscle relaxant', 'antiparkinson drugs', 'drugs used in vaginal an ...
# Results: [[{'entity_group': 'Medication', 'score': 0.9998016, 'word': 'im', 'start': 0, 'end': 2}, {'entity_group': 'Medication', 'score': 0.9184598, 'word': '##munosuppressant', 'start': 2, 'end': 17}], [{'entity_group': 'Medication', 'score': 0.92296624, 'word': 'hydrocortisone', 'start': 0, 'end': 14}, {'entity_group': 'Therapeutic_procedure', 'score': 0.71817887, 'word': 'combined preparations', 'start': 17, 'end': 38}], [{'entity_group': 'Administration', 'score': 0.93662393, 'word': 'topical', 'start': 0, 'end': 7}, {'entity_group': 'Therapeutic_procedure', 'score': 0.49922165, 'word': 'anti', 'start': 8, 'end': 12}, {'entity_group': 'Detailed_description', 'score': 0.96692693, 'word': '##viral', 'start': 12, 'end': 17}, {'entity_group': 'Therapeutic_procedure', 'score': 0.5808506, 'word': 'preparations', 'start': 18, 'end': 30}], [{'entity_group': 'Disease_disorder', 'score': 0.77169335, 'word': 'herpes', 'start': 0, 'end': 6}, {'entity_group': 'Disease_disorder', 'score': 0.5988854, 'word': 'simplex', 'start': 7, 'end': 14}, {'entity_group': 'Disease_disorder', 'score': 0.9607478, 'word': 'var', 'start': 17, 'end': 20}, {'entity_group': 'Disease_disorder', 'score': 0.90399384, 'word': '##lla - zost', 'start': 23, 'end': 31}, {'entity_group': 'Disease_disorder', 'score': 0.7337594, 'word': '##er virus', 'start': 31, 'end': 39}, {'entity_group': 'Disease_disorder', 'score': 0.99973863, 'word': 'infections', 'start': 40, 'end': 50}], [{'entity_group': 'Diagnostic_procedure', 'score': 0.9906392, 'word': 'ophthalmic anti - viral products', 'start': 0, 'end': 30}], [{'entity_group': 'Therapeutic_procedure', 'score': 0.8836351, 'word': 'antidote preparations', 'start': 0, 'end': 21}], [{'entity_group': 'Detailed_description', 'score': 0.93485177, 'word': 'combined', 'start': 0, 'end': 8}, {'entity_group': 'Therapeutic_procedure', 'score': 0.93598926, 'word': 'bronchodilators', 'start': 9, 'end': 24}], [{'entity_group': 'Diagnostic_procedure', 'score': 0.9383651, 'word': 'oral retinoid preparations', 'start': 0, 'end': 26}], [{'entity_group': 'Therapeutic_procedure', 'score': 0.99399763, 'word': 'haemodialysis solutions', 'start': 0, 'end': 23}], [{'entity_group': 'Medication', 'score': 0.579399, 'word': 'carbonic', 'start': 0, 'end': 8}, {'entity_group': 'Therapeutic_procedure', 'score': 0.44831598, 'word': 'an', 'start': 9, 'end': 11}, {'entity_group': 'Medication', 'score': 0.47514462, 'word': '##hy', 'start': 11, 'end': 13}, {'entity_group': 'Therapeutic_procedure', 'score': 0.44827783, 'word': '##dra', 'start': 13, 'end': 16}, {'entity_group': 'Medication', 'score': 0.3764263, 'word': '##se inhibitor', 'start': 16, 'end': 28}], [{'entity_group': 'Medication', 'score': 0.99170846, 'word': 'non', 'start': 0, 'end': 3}, {'entity_group': 'Medication', 'score': 0.983231, 'word': 'steroidal anti - inflammatory drugs', 'start': 4, 'end': 37}, {'entity_group': 'Medication', 'score': 0.83558786, 'word': 'nsaids', 'start': 39, 'end': 45}], [{'entity_group': 'Medication', 'score': 0.97521734, 'word': 'drugs', 'start': 0, 'end': 5}, {'entity_group': 'Disease_disorder', 'score': 0.9525166, 'word': 'osteoarthritis', 'start': 10, 'end': 24}], [{'entity_group': 'Medication', 'score': 0.5304499, 'word': 'herbal', 'start': 0, 'end': 6}, {'entity_group': 'Diagnostic_procedure', 'score': 0.4843457, 'word': 'nut', 'start': 11, 'end': 14}, {'entity_group': 'Medication', 'score': 0.576552, 'word': '##raceutical', 'start': 14, 'end': 24}, {'entity_group': 'Diagnostic_procedure', 'score': 0.55170155, 'word': '##s', 'start': 24, 'end': 25}], [{'entity_group': 'Medication', 'score': 0.7210219, 'word': 'drugs', 'start': 0, 'end': 5}, {'entity_group': 'History', 'score': 0.6896461, 'word': 'gout', 'start': 14, 'end': 18}], [{'entity_group': 'Diagnostic_procedure', 'score': 0.76002306, 'word': 'bp', 'start': 0, 'end': 2}, {'entity_group': 'Sign_symptom', 'score': 0.51697785, 'word': '##h', 'start': 2, 'end': 3}, {'entity_group': 'Detailed_description' ...
# Result: {'entity_group': 'Medication', 'score': 0.9998016, 'word': 'im', 'start': 0, 'end': 2}
# Result: {'entity_group': 'Medication', 'score': 0.9184598, 'word': '##munosuppressant', 'start': 2, 'end': 17}
# Result: {'entity_group': 'Medication', 'score': 0.92296624, 'word': 'hydrocortisone', 'start': 0, 'end': 14}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.71817887, 'word': 'combined preparations', 'start': 17, 'end': 38}
# Result: {'entity_group': 'Administration', 'score': 0.93662393, 'word': 'topical', 'start': 0, 'end': 7}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.49922165, 'word': 'anti', 'start': 8, 'end': 12}
# Result: {'entity_group': 'Detailed_description', 'score': 0.96692693, 'word': '##viral', 'start': 12, 'end': 17}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0
 'start': 14, 'end': 16}
# Result: {'entity_group': 'Biological_structure', 'score': 0.9965019, 'word': '##ginal', 'start': 16, 'end': 21}
# Result: {'entity_group': 'Biological_structure', 'score': 0.982585, 'word': 'vulval condition', 'start': 26, 'end': 42}
# Result: {'entity_group': 'Medication', 'score': 0.6691085, 'word': 'cough', 'start': 0, 'end': 5}
# Result: {'entity_group': 'Sign_symptom', 'score': 0.49063745, 'word': 'suppress', 'start': 6, 'end': 14}
# Result: {'entity_group': 'Medication', 'score': 0.78154844, 'word': '##ant', 'start': 14, 'end': 17}
# Result: {'entity_group': 'Detailed_description', 'score': 0.9999193, 'word': 'regional', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Medication', 'score': 0.47094807, 'word': 'an', 'start': 9, 'end': 11}
# Result: {'entity_group': 'Sign_symptom', 'score': 0.3375571, 'word': '##esthesia', 'start': 11, 'end': 19}
# Result: {'entity_group': 'Detailed_description', 'score': 0.99914896, 'word': 'loop', 'start': 0, 'end': 4}
# Result: {'entity_group': 'Medication', 'score': 0.88755655, 'word': 'diuretics', 'start': 5, 'end': 14}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.8029793, 'word': 'ulcerative colitis', 'start': 0, 'end': 18}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.9618931, 'word': 'nasal decongestants', 'start': 0, 'end': 19}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.96410656, 'word': 'nasal preparations', 'start': 28, 'end': 46}
# Result: {'entity_group': 'Detailed_description', 'score': 0.5854759, 'word': 'oral', 'start': 0, 'end': 4}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9588614, 'word': 'nutritional preparations', 'start': 5, 'end': 29}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.95487666, 'word': 'minerals in', 'start': 0, 'end': 11}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.8522018, 'word': 'bone formation', 'start': 12, 'end': 26}
# Result: {'entity_group': 'Detailed_description', 'score': 0.98385644, 'word': 'specific', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.987396, 'word': 'mineral &', 'start': 9, 'end': 18}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.8556504, 'word': 'vitamin combined preparations', 'start': 19, 'end': 48}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.99980927, 'word': 'supportive care therapy', 'start': 0, 'end': 23}
# Result: {'entity_group': 'Medication', 'score': 0.95356506, 'word': 'drugs', 'start': 0, 'end': 5}
# Result: {'entity_group': 'Biological_structure', 'score': 0.9999368, 'word': 'an', 'start': 14, 'end': 16}
# Result: {'entity_group': 'Biological_structure', 'score': 0.99854326, 'word': '##o - rectal region', 'start': 16, 'end': 31}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.66527754, 'word': 'vaso', 'start': 0, 'end': 4}
# Result: {'entity_group': 'Detailed_description', 'score': 0.38141567, 'word': 'protective', 'start': 5, 'end': 15}
# Result: {'entity_group': 'Detailed_description', 'score': 0.9998385, 'word': 'broad spectrum', 'start': 0, 'end': 14}
# Result: {'entity_group': 'Medication', 'score': 0.9944852, 'word': 'penicillins', 'start': 15, 'end': 26}
# ...
# Result: {'entity_group': 'Sign_symptom', 'score': 0.99549574, 'word': '##ypo - sensitisation', 'start': 33, 'end': 50}
# Result: {'entity_group': 'Medication', 'score': 0.9984569, 'word': 'growth hormone antagonist', 'start': 0, 'end': 25}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.5368074, 'word': 'anti neo', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.6784281, 'word': '##pl', 'start': 8, 'end': 10}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.73722386, 'word': '##astic preparations', 'start': 10, 'end': 28}
# Result: {'entity_group': 'Detailed_description', 'score': 0.33770502, 'word': 'va', 'start': 0, 'end': 2}
# Result: {'entity_group': 'Detailed_description', 'score': 0.23926948, 'word': '##so', 'start': 2, 'end': 4}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.36536005, 'word': '##con', 'start': 4, 'end': 7}
# Result: {'entity_group': 'Sign_symptom', 'score': 0.43371654, 'word': '##st', 'start': 7, 'end': 9}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.36644846, 'word': '##ric', 'start': 9, 'end': 12}
# Result: {'entity_group': 'Biological_structure', 'score': 0.72677666, 'word': 've', 'start': 16, 'end': 18}
# Result: {'entity_group': 'Biological_structure', 'score': 0.7941304, 'word': '##not', 'start': 18, 'end': 21}
# Result: {'entity_group': 'Biological_structure', 'score': 0.5400937, 'word': '##onic', 'start': 21, 'end': 25}
# Result: {'entity_group': 'Medication', 'score': 0.9963996, 'word': 'ocular perioperative drugs', 'start': 0, 'end': 26}
# Result: {'entity_group': 'Medication', 'score': 0.9202675, 'word': 'appetite suppressant drugs', 'start': 0, 'end': 26}
# Result: {'entity_group': 'Medication', 'score': 0.92140293, 'word': 'anti - obesity drugs', 'start': 27, 'end': 45}
# Result: {'entity_group': 'Detailed_description', 'score': 0.8558838, 'word': 'perito', 'start': 0, 'end': 6}
# Result: {'entity_group': 'Detailed_description', 'score': 0.75692105, 'word': '##neal', 'start': 6, 'end': 10}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.

# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9707075, 'word': 'male sex hormones (', 'start': 0, 'end': 19}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9823873, 'word': 'and', 'start': 19, 'end': 22}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.98717344, 'word': '##rogens', 'start': 22, 'end': 28}
# Result: {'entity_group': 'Coreference', 'score': 0.88891447, 'word': 'glycopeptide', 'start': 0, 'end': 12}
# Result: {'entity_group': 'Detailed_description', 'score': 0.9952493, 'word': 'selective', 'start': 0, 'end': 9}
# Result: {'entity_group': 'Medication', 'score': 0.34232524, 'word': 'va', 'start': 10, 'end': 12}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.5017924, 'word': '##sop', 'start': 12, 'end': 15}
# Result: {'entity_group': 'Medication', 'score': 0.6379427, 'word': '##ressin', 'start': 15, 'end': 21}
# Result: {'entity_group': 'Detailed_description', 'score': 0.48995686, 'word': 'v', 'start': 22, 'end': 23}
# Result: {'entity_group': 'Medication', 'score': 0.5691876, 'word': '##2 - receptor antagonist', 'start': 23, 'end': 44}
# Result: {'entity_group': 'Medication', 'score': 0.81815803, 'word': 'central depolarizing muscle relaxants', 'start': 0, 'end': 37}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9056946, 'word': 'anti - gallstones', 'start': 0, 'end': 15}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.999671, 'word': 'bile acids', 'start': 23, 'end': 33}
# Result: {'entity_group': 'Administration', 'score': 0.9543747, 'word': 'topical', 'start': 0, 'end': 7}
# Result: {'entity_group': 'Detailed_description', 'score': 0.40385836, 'word': 'urea', 'start': 8, 'end': 12}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.5053187, 'word': 'preparations', 'start': 13, 'end': 25}
# Result: {'entity_group': 'Medication', 'score': 0.46500874, 'word': 'vitamin', 'start': 0, 'end': 7}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.53772885, 'word': '- a preparations', 'start': 7, 'end': 22}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9987062, 'word': 'soluble guanylate cyclase', 'start': 14, 'end': 39}
# Result: {'entity_group': 'History', 'score': 0.93587947, 'word': 'substance dependence', 'start': 14, 'end': 34}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.7223358, 'word': 'vitamin - c preparations', 'start': 0, 'end': 22}
# Result: {'entity_group': 'Detailed_description', 'score': 0.8457431, 'word': 'diaper', 'start': 14, 'end': 20}
# Result: {'entity_group': 'Sign_symptom', 'score': 0.5923541, 'word': 'rash', 'start': 21, 'end': 25}
#               Entity Group                       Word     Score  \
# 0               Medication             hydrocortisone  0.922966
# 1    Therapeutic_procedure      combined preparations  0.718179
# 2           Administration                    topical  0.936624
# 3    Therapeutic_procedure                       anti  0.499222
# 4    Therapeutic_procedure               preparations  0.580851
# ..                     ...                        ...       ...
# 572   Diagnostic_procedure  soluble guanylate cyclase  0.998706
# 573                History       substance dependence  0.935879
# 574   Diagnostic_procedure   vitamin - c preparations  0.722336
# 575   Detailed_description                     diaper  0.845743
# 576           Sign_symptom                       rash  0.592354
#
#                                     Sentence
# 0     hydrocortisone & combined preparations
# 1     hydrocortisone & combined preparations
# 2             topical antiviral preparations
# 3             topical antiviral preparations
# 4             topical antiviral preparations
# ..                                       ...
# 572  stimulator of soluble guanylate cyclase
# 573       drugs used in substance dependence
# 574                   vitamin-c preparations
# 575                drugs used in diaper rash
# 576                drugs used in diaper rash
#
# [577 rows x 4 columns]

# %%
results_df
# Out:
#               Entity Group                       Word     Score  \
# 0               Medication             hydrocortisone  0.922966
# 1    Therapeutic_procedure      combined preparations  0.718179
# 2           Administration                    topical  0.936624
# 3    Therapeutic_procedure                       anti  0.499222
# 4    Therapeutic_procedure               preparations  0.580851
# ..                     ...                        ...       ...
# 572   Diagnostic_procedure  soluble guanylate cyclase  0.998706
# 573                History       substance dependence  0.935879
# 574   Diagnostic_procedure   vitamin - c preparations  0.722336
# 575   Detailed_description                     diaper  0.845743
# 576           Sign_symptom                       rash  0.592354
#
#                                     Sentence
# 0     hydrocortisone & combined preparations
# 1     hydrocortisone & combined preparations
# 2             topical antiviral preparations
# 3             topical antiviral preparations
# 4             topical antiviral preparations
# ..                                       ...
# 572  stimulator of soluble guanylate cyclase
# 573       drugs used in substance dependence
# 574                   vitamin-c preparations
# 575                drugs used in diaper rash
# 576                drugs used in diaper rash
#
# [577 rows x 4 columns]

# %%
results_df.to_csv('drug_class_results.csv', index=False)

# %%
import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")

class DRUG_CLASS_CLASSIFICATION():

    def __init__(self):
        self.pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0) # pass device=0 if using gpu
        df = pd.read_csv('cleaned_generic_df_main.csv')
        drug_class_list = df['drug_class'].unique().tolist()
        self.all_details = drug_class_list

    def classify_presciption_drugs(self):
        all_results = []
        all_details = self.all_details
        print(f'All Details: {all_details}')    
        for detail in all_details:
            if detail is not None:
                print(f'Detail: {detail}')
                # Pass the detail as a list to the pipeline
                full_results = self.pipe([detail])
                print(f'Results: {full_results}')
                for results in full_results:
                    for result in results:
                        if result is not None:
                            print(f'Result: {result}')
                            if len(result['word']) >= 4 and '#' not in result['word']:
                                all_results.append({'Entity Group': result['entity_group'], 'Word': result['word'], 'Score': result['score'], 'Detail': detail})
        # Return an empty DataFrame if no results are found
        if not all_results:
            return pd.DataFrame(columns=['Entity Group', 'Word', 'Score', 'Detail'])
        return pd.DataFrame(all_results)

# Create an instance of the DRUG_CLASS_CLASSIFICATION class
drug_classifier = DRUG_CLASS_CLASSIFICATION()

# Classify the prescription drugs and save results in a pandas DataFrame
results_df = drug_classifier.classify_presciption_drugs()

# Print the DataFrame
print(results_df)
# Out:
# All Details: ['immunosuppressant', 'hydrocortisone & combined preparations', 'topical antiviral preparations', 'herpes simplex & varicella-zoster virus infections', 'ophthalmic anti-viral products', 'antidote preparations', 'combined bronchodilators', 'oral retinoid preparations', 'haemodialysis solutions', 'carbonic anhydrase inhibitor', 'non-steroidal anti-inflammatory drugs (nsaids)', 'drugs for osteoarthritis', 'herbal and nutraceuticals', 'drugs used in gout', nan, 'bph/ urinary retention/ urinary incontinence', 'vitamin in bone formation', 'combined preparations: inhibiting bone resorption', 'bisphosphonate preparations', 'protein kinase inhibitor', 'ophthalmic anti-allergic preparations', 'plasma expanders', 'anthelmintic', 'atypical anti-depressant drugs', 'cytotoxic chemotherapy', 'tyrosine kinase inhibitor', 'vaccines, anti-sera & immunoglobulin', 'other adrenoceptor stimulants', 'supplements & adjuvant therapy', 'drugs used in chronic kidney dialysis', 'parenteral nutritional preparations', 'aminoglycosides', 'cough expectorants & mucolytics', 'anti-hypertensive', 'respiratory viral infections (influenza)', 'anticholinergics', 'antacid with laxative action', 'antacids', 'miscellaneous topical agents', 'fibrinolytics (thrombolytics)', 'benzodiazepine sedatives', 'haemostatics', 'prostaglandin analogues', 'other preparations', 'topical antifungal preparations', 'combined antihypertensive preparations', 'anti-anginal & lipid lowering drugs', 'calcium-channel blockers', 'combined anxiolytics & anti-depressant drugs', 'tricyclic anti-depressant', 'atypical neuroleptic drugs', 'potassium channel blockers', 'bronchodilator', 'bulk-forming laxatives', 'anti-malarial drugs', 'cns stimulant drugs', 'immunomodulator', 'anti-emetic drugs', 'disease-modifying antirheumatic drugs (dmards)', 'anti-oxidant multivitamin multimineral preparations', 'antihaemophilic factor', 'other ophthalmic preparations', 'echinocandins', 'topical analgesics', 'specific mineral preparations', 'anti-histamine preparations', 'acne treatment preparations', 'cytotoxic immunosuppressants', 'targeted cancer therapy', 'drugs for erectile dysfunction', 'mydriatic and cycloplegic agents', 'non depolarizing muscle relaxants', 'other anti-anginal & anti-ischaemic drugs', 'other lipid regulating drugs', 'beta-adrenoceptor blocking drugs', 'anticholinergics (antimuscarinics)/ anti-spasmodics', 'anti-fungal or anti-bacterial ear drops', 'nasal steroid preparations', 'respiratory corticosteroids', 'contrast medium for diagnostic procedures', 'short-acting selective & 2-adrenoceptor stimulants', 'irrigation during various surgical procedures', 'centrally acting skeletal muscle relaxants', 'ophthalmic antibacterial drugs', 'other beta-lactam antibiotics', 'macrolides', 'cholagogues, cholelitholytics & hepatic protectors', 'betamethasone & combined preparations', 'corticosteroid', "drugs used in meniere's diseases", 'anti-oxidant multivitamin preparations', 'benzylpenicillin & phenoxymethyl penicillin', 'parasiticidal preparations', 'other scalp preparations', 'topical anti-inflammatory preparations', 'other antifungal preparations', 'topical local anesthetics', 'vitamin-e preparations', 'local & surface anesthesia', 'long acting penicillin', 'stimulant purgatives', 'combination insulin', 'drugs for miotics and glaucoma', 'non-sedating antihistamines', 'hormonal chemotherapy', 'anti-platelet drugs', 'aural steroid & antibiotic combined preparations', 'phlebotonic & vascular protecting preparation', 'ophthalmic steroid - antibiotic combined preparations', 'other topical corticosteroids', 'bleaching and disinfectants', 'ophthalmic non-steroid drugs', 'enzymes', 'adjunct anti-epileptic drugs', 'benzodiazepine antagonist', 'anti adrenergic agent (beta blockers)', 'angiotensin-ll receptor blocker', 'nasal anti-histamine preparations', 'topical vitamin d & related preparations', 'local antipruritic', 'painkiller muscle relaxant', 'antiparkinson drugs', 'drugs used in vagin ...
# Detail: immunosuppressant
# Results: [[{'entity_group': 'Medication', 'score': 0.9998016, 'word': 'im', 'start': 0, 'end': 2}, {'entity_group': 'Medication', 'score': 0.9184598, 'word': '##munosuppressant', 'start': 2, 'end': 17}]]
# Result: {'entity_group': 'Medication', 'score': 0.9998016, 'word': 'im', 'start': 0, 'end': 2}
# Result: {'entity_group': 'Medication', 'score': 0.9184598, 'word': '##munosuppressant', 'start': 2, 'end': 17}
# Detail: hydrocortisone & combined preparations
# Results: [[{'entity_group': 'Medication', 'score': 0.92296624, 'word': 'hydrocortisone', 'start': 0, 'end': 14}, {'entity_group': 'Therapeutic_procedure', 'score': 0.71817887, 'word': 'combined preparations', 'start': 17, 'end': 38}]]
# Result: {'entity_group': 'Medication', 'score': 0.92296624, 'word': 'hydrocortisone', 'start': 0, 'end': 14}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.71817887, 'word': 'combined preparations', 'start': 17, 'end': 38}
# Detail: topical antiviral preparations
# Results: [[{'entity_group': 'Administration', 'score': 0.93662393, 'word': 'topical', 'start': 0, 'end': 7}, {'entity_group': 'Therapeutic_procedure', 'score': 0.49922165, 'word': 'anti', 'start': 8, 'end': 12}, {'entity_group': 'Detailed_description', 'score': 0.96692693, 'word': '##viral', 'start': 12, 'end': 17}, {'entity_group': 'Therapeutic_procedure', 'score': 0.5808506, 'word': 'preparations', 'start': 18, 'end': 30}]]
# Result: {'entity_group': 'Administration', 'score': 0.93662393, 'word': 'topical', 'start': 0, 'end': 7}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.49922165, 'word': 'anti', 'start': 8, 'end': 12}
# Result: {'entity_group': 'Detailed_description', 'score': 0.96692693, 'word': '##viral', 'start': 12, 'end': 17}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.5808506, 'word': 'preparations', 'start': 18, 'end': 30}
# Detail: herpes simplex & varicella-zoster virus infections
# Results: [[{'entity_group': 'Disease_disorder', 'score': 0.77169335, 'word': 'herpes', 'start': 0, 'end': 6}, {'entity_group': 'Disease_disorder', 'score': 0.5988854, 'word': 'simplex', 'start': 7, 'end': 14}, {'entity_group': 'Disease_disorder', 'score': 0.9607478, 'word': 'var', 'start': 17, 'end': 20}, {'entity_group': 'Disease_disorder', 'score': 0.90399384, 'word': '##lla - zost', 'start': 23, 'end': 31}, {'entity_group': 'Disease_disorder', 'score': 0.7337594, 'word': '##er virus', 'start': 31, 'end': 39}, {'entity_group': 'Disease_disorder', 'score': 0.99973863, 'word': 'infections', 'start': 40, 'end': 50}]]
# Result: {'entity_group': 'Disease_disorder', 'score': 0.77169335, 'word': 'herpes', 'start': 0, 'end': 6}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.5988854, 'word': 'simplex', 'start': 7, 'end': 14}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.9607478, 'word': 'var', 'start': 17, 'end': 20}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.90399384, 'word': '##lla - zost', 'start': 23, 'end': 31}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.7337594, 'word': '##er virus', 'start': 31, 'end': 39}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.99973863, 'word': 'infections', 'start': 40, 'end': 50}
# Detail: ophthalmic anti-viral products
# Results: [[{'entity_group': 'Diagnostic_procedure', 'score': 0.9906392, 'word': 'ophthalmic anti - viral products', 'start': 0, 'end': 30}]]
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9906392, 'word': 'ophthalmic anti - viral products', 'start': 0, 'end': 30}
# Detail: antidote preparations
# Results: [[{'entity_group': 'Therapeutic_procedure', 'score': 0.8836351, 'word': 'antidote preparations', 'start': 0, 'end': 21}]]
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.8836351, 'word': 'antidote preparations', 'start': 0, 'end': 21}
# Detail: combined bronchodilators
# Results: [[{'entity_group': 'Detailed_description', 'score': 0.93485177, 'word': 'combined', 'start': 0, 'end': 8}, {'entity_group': 'Therapeutic_procedure', 'score': 0.93598926, 'word': 'bronchodilators', 'start': 9, 'end': 24}]]
# Result: {'entity_group': 'Detailed_description', 'score': 0.93485177, 'word': 'combined', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.93598926, 'word': 'bronchodilators', 'start': 9, 'end': 24}
# Detail: oral retinoid preparations
# Results: [[{'entity_group': 'Diagnostic_procedure', 'score': 0.9383651, 'word': 'oral retinoid preparations', 'start': 0, 'end': 26}]]
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9383651, 'word': 'oral retinoid preparations', 'start': 0, 'end': 26}
# Detail: haemodialysis solutions
# Results: [[{'entity_group': 'Therapeutic_procedure', 'score': 0.99399763, 'word': 'haemodialysis solutions', 'start': 0, 'end': 23}]]
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.99399763, 'word': 'haemodialysis solutions', 'start': 0, 'end': 23}
# Detail: carbonic anhydrase inhibitor
# Results: [[{'entity_group': 'Medication', 'score': 0.579399, 'word': 'carbonic', 'start': 0, 'end': 8}, {'entity_group': 'Therapeutic_procedure', 'score': 0.44831598, 'word': 'an', 'start': 9, 'end': 11}, {'entity_group': 'Medication', 'score': 0.47514462, 'word': '##hy', 'start': 11, 'end': 13}, {'entity_group': 'Therapeutic_procedure', 'score': 0.44827783, 'word': '##dra', 'start': 13, 'end': 16}, {'entity_group': 'Medication', 'score': 0.3764263, 'word': '##se inhibitor', 'start': 16, 'end': 28}]]
# Result: {'entity_group': 'Medication', 'score': 0.579399, 'word': 'carbonic', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.44831598, 'word': 'an', 'start': 9, 'end': 11}
# Result: {'entity_group': 'Medication', 'score': 0.47514462, 'word': '##hy', 'start': 11, 'end': 13}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.44827783, 'word': '##dra', 'start': 13, 'end': 16}
# Result: {'entity_group': 'Medication', 'score': 0.3764263, 'word': '##se inhibitor', 'start': 16, 'end': 28}
# Detail: non-steroidal anti-inflammatory drugs (nsaids)
# Results: [[{'entity_group': 'Medication', 'score': 0.99170846, 'word': 'non', 'start': 0, 'end': 3}, {'entity_group': 'Medication', 'score': 0.983231, 'word': 'steroidal anti - inflammatory drugs', 'start': 4, 'end': 37}, {'entity_group': 'Medication', 'score': 0.83558786, 'word': 'nsaids', 'start': 39, 'end': 45}]]
# Result: {'entity_group': 'Medication', 'score': 0.99170846, 'word': 'non', 'start': 0, 'end': 3}
# Result: {'entity_group': 'Medication', 'score': 0.983231, 'word': 'steroidal anti - inflammatory drugs', 'start': 4, 'end': 37}
# Result: {'entity_group': 'Medication', 'score': 0.83558786, 'word': 'nsaids', 'start': 39, 'end': 45}
# Detail: drugs for osteoarthritis
# Results: [[{'entity_group': 'Medication', 'score': 0.97521734, 'word': 'drugs', 'start': 0, 'end': 5}, {'entity_group': 'Disease_disorder', 'score': 0.9525166, 'word': 'osteoarthritis', 'start': 10, 'end': 24}]]
# Result: {'entity_group': 'Medication', 'score': 0.97521734, 'word': 'drugs', 'start': 0, 'end': 5}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.9525166, 'word': 'osteoarthritis', 'start': 10, 'end': 24}
# Detail: herbal and nutraceuticals
# Results: [[{'entity_group': 'Medication', 'score': 0.5304499, 'word': 'herbal', 'start': 0, 'end': 6}, {'entity_group': 'Diagnostic_procedure', 'score': 0.4843457, 'word': 'nut', 'start': 11, 'end': 14}, {'entity_group': 'Medication', 'score': 0.576552, 'word': '##raceutical', 'start': 14, 'end': 24}, {'entity_group': 'Diagnostic_procedure', 'score': 0.55170155, 'word': '##s', 'start': 24, 'end': 25}]]
# Result: {'entity_group': 'Medication', 'score': 0.5304499, 'word': 'herbal', 'start': 0, 'end': 6}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.4843457, 'word': 'nut', 'start': 11, 'end': 14}
# Result: {'entity_group': 'Medication', 'score': 0.576552, 'word': '##raceutical', 'start': 14, 'end': 24}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.55170155, 'word': '##s', 'start': 24, 'end': 25}
# Detail: drugs used in gout
# Results: [[{'entity_group': 'Medication', 'score': 0.7210219, 'word': 'drugs', 'start': 0, 'end': 5}, {'entity_group': 'History', 'score': 0.6896461, 'word': 'gout', 'start': 14, 'end': 18}]]
# Result: {'entity_group': 'Medication', 'score': 0.7210219, 'word': 'drugs', 'start': 0, 'end': 5}
# Result: {'entity_group': 'History', 'score': 0.6896461, 'word': 'gout', 'start': 14, 'end': 18}
# Detail: nan
# c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\learn_django\tryagain\presciption_classification\presciption.ipynb Cell 7 in <cell line: 41>()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=37'>38</a> drug_classifier = DRUG_CLASS_CLASSIFICATION()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=39'>40</a> # Classify the prescription drugs and save results in a pandas DataFrame
# ---> <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=40'>41</a> results_df = drug_classifier.classify_presciption_drugs()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=42'>43</a> # Print the DataFrame
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=43'>44</a> print(results_df)
#
# d:\learn_django\tryagain\presciption_classification\presciption.ipynb Cell 7 in DRUG_CLASS_CLASSIFICATION.classify_presciption_drugs(self)
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=21'>22</a> print(f'Detail: {detail}')
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a> # Pass the detail as a list to the pipeline
# ---> <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=23'>24</a> full_results = self.pipe([detail])
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a> print(f'Results: {full_results}')
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a> for results in full_results:
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\token_classification.py:249, in TokenClassificationPipeline.__call__(self, inputs, **kwargs)
#     246 if offset_mapping:
#     247     kwargs["offset_mapping"] = offset_mapping
# --> 249 return super().__call__(inputs, **kwargs)
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\base.py:1101, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1097 if can_use_iterator:
#    1098     final_iterator = self.get_iterator(
#    1099         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1100     )
# -> 1101     outputs = list(final_iterator)
#    1102     return outputs
#    1103 else:
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\pt_utils.py:266, in PipelinePackIterator.__next__(self)
#     263             return accumulator
#     265 while not is_last:
# --> 266     processed = self.infer(next(self.iterator), **self.params)
#     267     if self.loader_batch_size is not None:
#     268         if isinstance(processed, torch.Tensor):
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\torch\utils\data\dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\torch\utils\data\dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\torch\utils\data\_utils\fetch.py:32, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      30 for _ in possibly_batched_index:
#      31     try:
# ---> 32         data.append(next(self.dataset_iter))
#      33     except StopIteration:
#      34         self.ended = True
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\pt_utils.py:183, in PipelineChunkIterator.__next__(self)
#     180     self.subiterator = self.infer(next(self.iterator), **self.params)
#     181 try:
#     182     # Try to return next item
# --> 183     processed = next(self.subiterator)
#     184 except StopIteration:
#     185     # When a preprocess iterator ends, we can start lookig at the next item
#     186     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)
#     189     # Another way to look at it, is we're basically flattening lists of lists
#     190     # into a single list, but with generators
#     191     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\token_classification.py:254, in TokenClassificationPipeline.preprocess(self, sentence, offset_mapping, **preprocess_params)
#     252 tokenizer_params = preprocess_params.pop("tokenizer_params", {})
#     253 truncation = True if self.tokenizer.model_max_length and self.tokenizer.model_max_length > 0 else False
# --> 254 inputs = self.tokenizer(
#     255     sentence,
#     256     return_tensors=self.framework,
#     257     truncation=truncation,
#     258     return_special_tokens_mask=True,
#     259     return_offsets_mapping=self.tokenizer.is_fast,
#     260     **tokenizer_params,
#     261 )
#     262 inputs.pop("overflow_to_sample_mapping", None)
#     263 num_chunks = len(inputs["input_ids"])
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\tokenization_utils_base.py:2561, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2559     if not self._in_target_context_manager:
#    2560         self._switch_to_input_mode()
# -> 2561     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2562 if text_target is not None:
#    2563     self._switch_to_target_mode()
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\tokenization_utils_base.py:2619, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2616         return False
#    2618 if not _is_valid_text_input(text):
# -> 2619     raise ValueError(
#    2620         "text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2621         "or `List[List[str]]` (batch of pretokenized examples)."
#    2622     )
#    2624 if text_pair is not None and not _is_valid_text_input(text_pair):
#    2625     raise ValueError(
#    2626         "text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2627         "or `List[List[str]]` (batch of pretokenized examples)."
#    2628     )
#
# ValueError: text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).

# %%
all_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\learn_django\tryagain\presciption_classification\presciption.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> all_results
#
# NameError: name 'all_results' is not defined

# %%
import pandas as pd
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")

class DRUG_CLASS_CLASSIFICATION():

    def __init__(self):
        self.pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple",device=0) # pass device=0 if using gpu
        df = pd.read_csv('cleaned_generic_df_main.csv')
        drug_class_list = df['drug_class'].unique().tolist()
        self.all_details = drug_class_list

    def classify_presciption_drugs(self):
        all_results = []
        all_details = self.all_details
        print(f'All Details: {all_details}')    
        for detail in all_details:
            if detail is not None:
                print(f'Detail: {detail}')
                results = self.pipe(detail)
                for result in results:
                    if result is not None:
                        print(f'Result: {result}')
                        if len(result['word']) >= 4 and '#' not in result['word']:
                            all_results.append({'Entity Group': result['entity_group'], 'Word': result['word'], 'Score': result['score'], 'Detail': detail})
        return pd.DataFrame(all_results)  # Move this line outside the for loop


# Create an instance of the DRUG_CLASS_CLASSIFICATION class
drug_classifier = DRUG_CLASS_CLASSIFICATION()

# Classify the prescription drugs and save results in a pandas DataFrame
results_df = drug_classifier.classify_presciption_drugs()

# Print the DataFrame
print(results_df)
# Out:
# All Details: ['immunosuppressant', 'hydrocortisone & combined preparations', 'topical antiviral preparations', 'herpes simplex & varicella-zoster virus infections', 'ophthalmic anti-viral products', 'antidote preparations', 'combined bronchodilators', 'oral retinoid preparations', 'haemodialysis solutions', 'carbonic anhydrase inhibitor', 'non-steroidal anti-inflammatory drugs (nsaids)', 'drugs for osteoarthritis', 'herbal and nutraceuticals', 'drugs used in gout', nan, 'bph/ urinary retention/ urinary incontinence', 'vitamin in bone formation', 'combined preparations: inhibiting bone resorption', 'bisphosphonate preparations', 'protein kinase inhibitor', 'ophthalmic anti-allergic preparations', 'plasma expanders', 'anthelmintic', 'atypical anti-depressant drugs', 'cytotoxic chemotherapy', 'tyrosine kinase inhibitor', 'vaccines, anti-sera & immunoglobulin', 'other adrenoceptor stimulants', 'supplements & adjuvant therapy', 'drugs used in chronic kidney dialysis', 'parenteral nutritional preparations', 'aminoglycosides', 'cough expectorants & mucolytics', 'anti-hypertensive', 'respiratory viral infections (influenza)', 'anticholinergics', 'antacid with laxative action', 'antacids', 'miscellaneous topical agents', 'fibrinolytics (thrombolytics)', 'benzodiazepine sedatives', 'haemostatics', 'prostaglandin analogues', 'other preparations', 'topical antifungal preparations', 'combined antihypertensive preparations', 'anti-anginal & lipid lowering drugs', 'calcium-channel blockers', 'combined anxiolytics & anti-depressant drugs', 'tricyclic anti-depressant', 'atypical neuroleptic drugs', 'potassium channel blockers', 'bronchodilator', 'bulk-forming laxatives', 'anti-malarial drugs', 'cns stimulant drugs', 'immunomodulator', 'anti-emetic drugs', 'disease-modifying antirheumatic drugs (dmards)', 'anti-oxidant multivitamin multimineral preparations', 'antihaemophilic factor', 'other ophthalmic preparations', 'echinocandins', 'topical analgesics', 'specific mineral preparations', 'anti-histamine preparations', 'acne treatment preparations', 'cytotoxic immunosuppressants', 'targeted cancer therapy', 'drugs for erectile dysfunction', 'mydriatic and cycloplegic agents', 'non depolarizing muscle relaxants', 'other anti-anginal & anti-ischaemic drugs', 'other lipid regulating drugs', 'beta-adrenoceptor blocking drugs', 'anticholinergics (antimuscarinics)/ anti-spasmodics', 'anti-fungal or anti-bacterial ear drops', 'nasal steroid preparations', 'respiratory corticosteroids', 'contrast medium for diagnostic procedures', 'short-acting selective & 2-adrenoceptor stimulants', 'irrigation during various surgical procedures', 'centrally acting skeletal muscle relaxants', 'ophthalmic antibacterial drugs', 'other beta-lactam antibiotics', 'macrolides', 'cholagogues, cholelitholytics & hepatic protectors', 'betamethasone & combined preparations', 'corticosteroid', "drugs used in meniere's diseases", 'anti-oxidant multivitamin preparations', 'benzylpenicillin & phenoxymethyl penicillin', 'parasiticidal preparations', 'other scalp preparations', 'topical anti-inflammatory preparations', 'other antifungal preparations', 'topical local anesthetics', 'vitamin-e preparations', 'local & surface anesthesia', 'long acting penicillin', 'stimulant purgatives', 'combination insulin', 'drugs for miotics and glaucoma', 'non-sedating antihistamines', 'hormonal chemotherapy', 'anti-platelet drugs', 'aural steroid & antibiotic combined preparations', 'phlebotonic & vascular protecting preparation', 'ophthalmic steroid - antibiotic combined preparations', 'other topical corticosteroids', 'bleaching and disinfectants', 'ophthalmic non-steroid drugs', 'enzymes', 'adjunct anti-epileptic drugs', 'benzodiazepine antagonist', 'anti adrenergic agent (beta blockers)', 'angiotensin-ll receptor blocker', 'nasal anti-histamine preparations', 'topical vitamin d & related preparations', 'local antipruritic', 'painkiller muscle relaxant', 'antiparkinson drugs', 'drugs used in vagin ...
# Detail: immunosuppressant
# Result: {'entity_group': 'Medication', 'score': 0.9998016, 'word': 'im', 'start': 0, 'end': 2}
# Result: {'entity_group': 'Medication', 'score': 0.9184598, 'word': '##munosuppressant', 'start': 2, 'end': 17}
# Detail: hydrocortisone & combined preparations
# Result: {'entity_group': 'Medication', 'score': 0.92296624, 'word': 'hydrocortisone', 'start': 0, 'end': 14}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.71817887, 'word': 'combined preparations', 'start': 17, 'end': 38}
# Detail: topical antiviral preparations
# Result: {'entity_group': 'Administration', 'score': 0.93662393, 'word': 'topical', 'start': 0, 'end': 7}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.49922165, 'word': 'anti', 'start': 8, 'end': 12}
# Result: {'entity_group': 'Detailed_description', 'score': 0.96692693, 'word': '##viral', 'start': 12, 'end': 17}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.5808506, 'word': 'preparations', 'start': 18, 'end': 30}
# Detail: herpes simplex & varicella-zoster virus infections
# Result: {'entity_group': 'Disease_disorder', 'score': 0.77169335, 'word': 'herpes', 'start': 0, 'end': 6}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.5988854, 'word': 'simplex', 'start': 7, 'end': 14}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.9607478, 'word': 'var', 'start': 17, 'end': 20}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.90399384, 'word': '##lla - zost', 'start': 23, 'end': 31}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.7337594, 'word': '##er virus', 'start': 31, 'end': 39}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.99973863, 'word': 'infections', 'start': 40, 'end': 50}
# Detail: ophthalmic anti-viral products
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9906392, 'word': 'ophthalmic anti - viral products', 'start': 0, 'end': 30}
# Detail: antidote preparations
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.8836351, 'word': 'antidote preparations', 'start': 0, 'end': 21}
# Detail: combined bronchodilators
# Result: {'entity_group': 'Detailed_description', 'score': 0.93485177, 'word': 'combined', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.93598926, 'word': 'bronchodilators', 'start': 9, 'end': 24}
# Detail: oral retinoid preparations
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.9383651, 'word': 'oral retinoid preparations', 'start': 0, 'end': 26}
# Detail: haemodialysis solutions
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.99399763, 'word': 'haemodialysis solutions', 'start': 0, 'end': 23}
# Detail: carbonic anhydrase inhibitor
# Result: {'entity_group': 'Medication', 'score': 0.579399, 'word': 'carbonic', 'start': 0, 'end': 8}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.44831598, 'word': 'an', 'start': 9, 'end': 11}
# Result: {'entity_group': 'Medication', 'score': 0.47514462, 'word': '##hy', 'start': 11, 'end': 13}
# Result: {'entity_group': 'Therapeutic_procedure', 'score': 0.44827783, 'word': '##dra', 'start': 13, 'end': 16}
# Result: {'entity_group': 'Medication', 'score': 0.3764263, 'word': '##se inhibitor', 'start': 16, 'end': 28}
# Detail: non-steroidal anti-inflammatory drugs (nsaids)
# Result: {'entity_group': 'Medication', 'score': 0.99170846, 'word': 'non', 'start': 0, 'end': 3}
# Result: {'entity_group': 'Medication', 'score': 0.983231, 'word': 'steroidal anti - inflammatory drugs', 'start': 4, 'end': 37}
# Result: {'entity_group': 'Medication', 'score': 0.83558786, 'word': 'nsaids', 'start': 39, 'end': 45}
# Detail: drugs for osteoarthritis
# Result: {'entity_group': 'Medication', 'score': 0.97521734, 'word': 'drugs', 'start': 0, 'end': 5}
# Result: {'entity_group': 'Disease_disorder', 'score': 0.9525166, 'word': 'osteoarthritis', 'start': 10, 'end': 24}
# Detail: herbal and nutraceuticals
# Result: {'entity_group': 'Medication', 'score': 0.5304499, 'word': 'herbal', 'start': 0, 'end': 6}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.4843457, 'word': 'nut', 'start': 11, 'end': 14}
# Result: {'entity_group': 'Medication', 'score': 0.576552, 'word': '##raceutical', 'start': 14, 'end': 24}
# Result: {'entity_group': 'Diagnostic_procedure', 'score': 0.55170155, 'word': '##s', 'start': 24, 'end': 25}
# Detail: drugs used in gout
# Result: {'entity_group': 'Medication', 'score': 0.7210219, 'word': 'drugs', 'start': 0, 'end': 5}
# Result: {'entity_group': 'History', 'score': 0.6896461, 'word': 'gout', 'start': 14, 'end': 18}
# Detail: nan
# c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\learn_django\tryagain\presciption_classification\presciption.ipynb Cell 6 in <cell line: 36>()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=32'>33</a> drug_classifier = DRUG_CLASS_CLASSIFICATION()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=34'>35</a> # Classify the prescription drugs and save results in a pandas DataFrame
# ---> <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=35'>36</a> results_df = drug_classifier.classify_presciption_drugs()
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=37'>38</a> # Print the DataFrame
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=38'>39</a> print(results_df)
#
# d:\learn_django\tryagain\presciption_classification\presciption.ipynb Cell 6 in DRUG_CLASS_CLASSIFICATION.classify_presciption_drugs(self)
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a> if detail is not None:
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>     print(f'Detail: {detail}')
# ---> <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a>     results = self.pipe(detail)
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a>     for result in results:
#      <a href='vscode-notebook-cell:/d%3A/learn_django/tryagain/presciption_classification/presciption.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a>         if result is not None:
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\token_classification.py:245, in TokenClassificationPipeline.__call__(self, inputs, **kwargs)
#     219 def __call__(self, inputs: Union[str, List[str]], **kwargs):
#     220     """
#     221     Classify each token of the text(s) given as inputs.
#     222
#    (...)
#     242           exists if the offsets are available within the tokenizer
#     243     """
# --> 245     _inputs, offset_mapping = self._args_parser(inputs, **kwargs)
#     246     if offset_mapping:
#     247         kwargs["offset_mapping"] = offset_mapping
#
# File c:\Users\rifat\miniconda3\envs\tf\lib\site-packages\transformers\pipelines\token_classification.py:40, in TokenClassificationArgumentHandler.__call__(self, inputs, **kwargs)
#      38     return inputs, None
#      39 else:
# ---> 40     raise ValueError("At least one input is required.")
#      42 offset_mapping = kwargs.get("offset_mapping")
#      43 if offset_mapping:
#
# ValueError: At least one input is required.

# %%
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
drug_class_classification = DRUG_CLASS_CLASSIFICATION()

# %%
drug_class=drug_class_classification.classify_presciption_drugs()
# Out:
# result: {'entity_group': 'Sign_symptom', 'score': 0.5923541, 'word': 'rash', 'start': 21, 'end': 25}

# %%
df
# Out:
#                     generic_name  \
# 0                     adalimumab
# 1     acyclovir + hydrocortisone
# 2            acyclovir (topical)
# 3               acyclovir (oral)
# 4         acyclovir (ophthalmic)
# ...                          ...
# 1706                  zinc oxide
# 1707                zinc orotate
# 1708                  zidovudine
# 1709                    zaleplon
# 1710                 zafirlukast
#
#                                              drug_class  \
# 0                                     immunosuppressant
# 1                hydrocortisone & combined preparations
# 2                        topical antiviral preparations
# 3     herpes simplex & varicella-zoster virus infect...
# 4                        ophthalmic anti-viral products
# ...                                                 ...
# 1706                          drugs used in diaper rash
# 1707                      specific mineral preparations
# 1708              drugs for hiv / anti-retroviral drugs
# 1709                           benzodiazepine hypnotics
# 1710                   leukotriene receptor antagonists
#
#                            indication  \
# 0                  ulcerative colitis
# 1                     herpes labialis
# 2                           sore lips
# 3       varicella zoster (chickenpox)
# 4             neonatal conjunctivitis
# ...                               ...
# 1706                   pressure sores
# 1707                  severe diarrhea
# 1708                    hiv infection
# 1709  insomnia and sleep disturbances
# 1710                   chronic asthma
#
#                                  indication_description  \
# 0        adalimumab is a tumor necrosis factor (tnf)...
# 1      acyclovir &amp; hydrocortisone cream is indic...
# 2      acyclovircream is a herpes simplex virus (hsv...
# 3      aciclovir is indicated for- \r\n \r\n the tre...
# 4      acyclovir is indicated for the treatment of h...
# ...                                                 ...
# 1706   zinc oxide helps treat and prevent diaper ras...
# 1707   oral zinc therapy is indicated in zinc defici...
# 1708     zidovudine, a nucleosidereverse transcripta...
# 1709   zaleplon is indicated for the short-term trea...
# 1710   zafirlukast is indicated for the prophylaxis ...
#
#                           therapeutic_class_description  \
# 0      disease-modifying antirheumatic drugs (dmards...
# 1           hydrocortisone &amp; combined preparations
# 2                       topical antiviral preparations
# 3      herpes simplex &amp; varicella-zoster virus i...
# 4                       ophthalmic anti-viral products
# ...                                                 ...
# 1706                         drugs used in diaper rash
# 1707                     specific mineral preparations
# 1708             drugs for hiv / anti-retroviral drugs
# 1709   benzodiazepine hypnotics, benzodiazepine seda...
# 1710                  leukotriene receptor antagonists
#
#                                pharmacology_description  \
# 0      adalimumab is a recombinant human igg1 monocl...
# 1      acyclovir is a synthetic purine nucleoside an...
# 2      acyclovir is an antiviral drug active against...
# 3      aciclovir is a synthetic purine derivative. a...
# 4      acyclovir is an antiviral agent which is high...
# ...                                                 ...
# 1706   zinc oxide is used to treat or prevent minor ...
# 1707   zinc, a major mineral,plays a part in almost ...
# 1708   zidovudine is converted intracellularly to zi...
# 1709   zaleplon is a newer non-benzodiazepine hypnot...
# 1710   zafirlukast is a selective and competitive le...
#
#                                      dosage_description  \
# 0       rheumatoid arthritis, psoriatic arthritis, a...
# 1      the cream should be topically applied 5 times...
# 2      acyclovircream should be applied five times p...
# 3      treatment of initial herpes simplex: 200 mg 5...
# 4      the dosage for all age groups is the same. a ...
# ...                                                 ...
# 1706   change wet and soiled diapers promptly, clean...
# 1707        adults : one tablet twice daily with meal.
# 1708   prophylaxis of hiv infection in neonates: \r\...
# 1709   the dose of zaleplon should be individualized...
# 1710   zafirlukast should be taken continuously.    ...
#
#                                 interaction_description  \
# 0      abatacept: increased risk of serious infectio...
# 1                                                   NaN
# 2      clinical experience has identified no interac...
# 3      probenecid reduces aciclovir excretion and so...
# 4      no clinically significant interactions have b...
# ...                                                 ...
# 1706   no hazardous drug interactions have been repo...
# 1707   concomitant intake of tetracycline, quinolone...
# 1708   decreased plasma concentration with rifampici...
# 1709   zaleplon has been shown to have minimal effec...
# 1710   zafirlukast may be administered with other th...
#
#                           contraindications_description  \
# 0      adalimumab should not be administered to pati...
# 1                  there is no known contraindication.
# 2      acyclovircream is contraindicated in patients...
# 3      aciclovir is contraindicated in patients know...
# 4      acyclovir is contraindicated in patients know...
# ...                                                 ...
# 1706   known hypersensitivity to any component of th...
# 1707                                                NaN
# 1708   hypersensitivity; abnormally low neutrophil c...
# 1709   zaleplon is contraindicated in patients with ...
# 1710   zafirlukast should not be given to patients w...
#
#                                side_effects_description
# 0      the most common adverse reaction with adalimu...
# 1      the following most common adverse reactions (...
# 2      the most common adverse reactions at the site...
# 3      rash, gastrointestinal disturbance, rise in b...
# 4      very common: superficial punctate keratopathy...
# ...                                                 ...
# 1706   usually well tolerated. extremely low frequen...
# 1707   zinc might cause nausea, vomiting, metallic t...
# 1708   dizziness, headache, malaise, myalgia, gi sym...
# 1709   side effects of zaleplon appear to be dose re...
# 1710    effect on ability to drive or operate machin...
#
# [1711 rows x 10 columns]
